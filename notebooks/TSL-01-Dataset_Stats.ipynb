# %%
import psycopg2
import pprint
from pprint import pprint

conn = psycopg2.connect('dbname=yelp user=tlappas host=/var/run/postgresql')
conn.set_session(autocommit=True)
cur = conn.cursor()

for table in ['user_info', 'business', 'review']:
    cur.execute("""
        SELECT column_name, data_type, character_maximum_length 
        FROM INFORMATION_SCHEMA.COLUMNS 
        WHERE table_name = %s;
    """, (table,))
    print('{}\n'.format(table))
    pprint(cur.fetchall())
    print('')
# Out:
# user_info
#
# [('user_id', 'character', 22),
#  ('name', 'text', None),
#  ('review_count', 'integer', None),
#  ('yelping_since', 'date', None),
#  ('friends', 'text', None),
#  ('useful', 'integer', None),
#  ('funny', 'integer', None),
#  ('cool', 'integer', None),
#  ('fans', 'integer', None),
#  ('elite', 'text', None),
#  ('average_stars', 'real', None),
#  ('compliment_hot', 'integer', None),
#  ('compliment_more', 'integer', None),
#  ('compliment_profile', 'integer', None),
#  ('compliment_cute', 'integer', None),
#  ('compliment_list', 'integer', None),
#  ('compliment_note', 'integer', None),
#  ('compliment_plain', 'integer', None),
#  ('compliment_cool', 'integer', None),
#  ('compliment_funny', 'integer', None),
#  ('compliment_writer', 'integer', None),
#  ('compliment_photos', 'integer', None)]
#
# business
#
# [('business_id', 'character', 22),
#  ('name', 'text', None),
#  ('address', 'text', None),
#  ('city', 'text', None),
#  ('state', 'text', None),
#  ('postal_code', 'text', None),
#  ('lat', 'real', None),
#  ('long', 'real', None),
#  ('stars', 'real', None),
#  ('review_count', 'integer', None),
#  ('is_open', 'boolean', None),
#  ('attributes', 'json', None),
#  ('categories', 'text', None),
#  ('hours', 'json', None)]
#
# review
#
# [('review_id', 'character', 22),
#  ('user_id', 'character', 22),
#  ('business_id', 'character', 22),
#  ('stars', 'integer', None),
#  ('review_date', 'date', None),
#  ('review_text', 'text', None),
#  ('useful', 'integer', None),
#  ('funny', 'integer', None),
#  ('cool', 'integer', None)]

# %%
# How many reviews?

cur.execute("""
    SELECT COUNT(*) 
    FROM review;
""")
print('Number of reviews: {}'.format(cur.fetchone()[0]))

# How many reviews with text? 

cur.execute("""
    SELECT COUNT(*) 
    FROM review
    WHERE (length(review.review_text) >= 1);
""")
print('Number of non-empty reviews: {}'.format(cur.fetchone()[0]))
# Out:
# Number of reviews: 6685900
# Number of non-empty reviews: 6685900

# %%
# How many users?

cur.execute("""
    SELECT COUNT(*)
    FROM user_info;
""")
print('Number of users: {}'.format(cur.fetchone()[0]))

# How many users with at least one review?

cur.execute("""
    SELECT COUNT(user_id) 
    FROM user_info 
    WHERE review_count > 0;
""")
print('Number of users with at least one review: {}'.format(cur.fetchone()[0]))

# How many elite users?
# Out:
# Number of users: 1637138
# Number of users with at least one review: 1637115

# %%
# How many businesses?

cur.execute("""
    SELECT COUNT(*)
    FROM business;
""")
print('Number of businesses: {}'.format(cur.fetchone()[0]))

# How many businesses with at least one review?

cur.execute("""
    SELECT COUNT(*)
    FROM business
    WHERE review_count > 0;
""")
print('Number of businesses with at least one review: {}'.format(cur.fetchone()[0]))

# How many resturants with at least one review?

cur.execute("""
    SELECT COUNT(*)
    FROM business
    WHERE review_count > 0 and categories LIKE '%Restaurants%';
""")
print('Number of resturants with at least one review: {}'.format(cur.fetchone()[0]))

# Where are they located?

cur.execute("""
    SELECT DISTINCT(city, state)
    FROM business;
""")
print('Cities with reviews:')
pprint(cur.fetchall())
# Out:
# Number of businesses: 192609
# Number of businesses with at least one review: 192609
# Number of resturants with at least one review: 59371
# Cities with reviews:
# [('("",AZ)',),
#  ('("110 Las Vegas",NV)',),
#  ('(Agincourt,ON)',),
#  ('(AGINCOURT,ON)',),
#  ('(Ahwahtukee,AZ)',),
#  ('(Ahwatukee,AZ)',),
#  ('("Ahwatukee Foothills Village",AZ)',),
#  ('(Airdrie,AB)',),
#  ('(Ajax,ON)',),
#  ('(Akron,OH)',),
#  ('(Alberta,AB)',),
#  ('(Alburg,VT)',),
#  ('(Alburgh,VT)',),
#  ('(Aliquippa,PA)',),
#  ('(Allegheny,PA)',),
#  ('(Allentown,PA)',),
#  ('("Allison Park",PA)',),
#  ('(Ambridge,PA)',),
#  ('(Amherst,OH)',),
#  ('(Ange-Gardien,QC)',),
#  ('(Anjou,QC)',),
#  ('(Ansnorveldt,ON)',),
#  ('(Anthem,AZ)',),
#  ('(Antioch,CA)',),
#  ('("Apache Junction",AZ)',),
#  ('("Apache Trail",AZ)',),
#  ('(Arizona,AZ)',),
#  ('(Arnold,PA)',),
#  ('(Arrowhead,AZ)',),
#  ('(Ashburn,ON)',),
#  ('(Aspinwall,PA)',),
#  ('(Auburn,OH)',),
#  ('("Auburn Township",OH)',),
#  ('("Auburn Twp",OH)',),
#  ('(Aurora,OH)',),
#  ('(Aurora,ON)',),
#  ('(Austin,TX)',),
#  ('(Avalon,PA)',),
#  ('(Avon,OH)',),
#  ('(AVON,OH)',),
#  ('(Avondale,AZ)',),
#  ('(Avondale,GA)',),
#  ('("Avon lake",OH)',),
#  ('("Avon Lake",OH)',),
#  ('(AZ,AZ)',),
#  ("(Baie-d'Urfe,QC)",),
#  ("(Baie-d'Urfé,QC)",),
#  ('(Bainbridge,OH)',),
#  ('("Bainbridge Township",OH)',),
#  ('(Bakerstown,PA)',),
#  ('(Baldwin,PA)',),
#  ('(Ballantyne,NC)',),
#  ('(Balzac,AB)',),
#  ('(Banksville,PA)',),
#  ('(Barberton,OH)',),
#  ('(Bath,BAS)',),
#  ('(Bath,OH)',),
#  ('("Bay Village",OH)',),
#  ('(Beachwood,OH)',),
#  ('("Beachwood ",OH)',),
#  ('(Beaconsfield,QC)',),
#  ('(Beauharnois,QC)',),
#  ('(Bedford,OH)',),
#  ('(Bedford,QC)',),
#  ('("Bedford Heights",OH)',),
#  ('("Bedford Hts",OH)',),
#  ('("Bedford Hts.",OH)',),
#  ('(Beeton,ON)',),
#  ('("Belle Vernon",PA)',),
#  ('(Belleville,WI)',),
#  ('(Bellevue,PA)',),
#  ('(Bellvue,PA)',),
#  ('(Belmont,NC)',),
#  ('(Beloeil,QC)',),
#  ('(Belœil,QC)',),
#  ('(Beltline,AB)',),
#  ('("Ben Avon",PA)',),
#  ('(Bentleyville,OH)',),
#  ('(Berea,AK)',),
#  ('(Berea,OH)',),
#  ('(Berry,WI)',),
#  ('("Bethel Park",PA)',),
#  ('("Black Earth",WI)',),
#  ('("Black Rock City",NV)',),
#  ('(Blainville,QC)',),
#  ('(Blakeney,NC)',),
#  ('(Blawnox,PA)',),
#  ('(Bloomfield,PA)',),
#  ('("Blue Diamond",NV)',),
#  ('("Blue Mounds",WI)',),
#  ('(Boisbriand,QC)',),
#  ('(Bois-des-Filion,QC)',),
#  ('(Bolton,ON)',),
#  ('("Bond Head",ON)',),
#  ('(Boston,PA)',),
#  ('("Boston Heights",OH)',),
#  ('(Boucherville,QC)',),
#  ('("boulder city",NV)',),
#  ('("Boulder City",NV)',),
#  ('(Braddock,PA)',),
#  ('(Bradford,ON)',),
#  ('("Bradford West Gwillimbury",ON)',),
#  ('(Bradfordwoods,PA)',),
#  ('(Brampton,ON)',),
#  ('(Bratenahl,OH)',),
#  ('(Brecksville,OH)',),
#  ('(Brentwood,PA)',),
#  ('(Bridgeville,PA)',),
#  ('(Broadlands,IL)',),
#  ('("Broadview Heights",OH)',),
#  ('("Broadview Hts",OH)',),
#  ('(Brooklin,ON)',),
#  ('(Brookline,PA)',),
#  ('(Brooklyn,NY)',),
#  ('(Brooklyn,OH)',),
#  ('(Brooklyn,WI)',),
#  ('("Brooklyn Heights",OH)',),
#  ('("Brooklyn Hts.",OH)',),
#  ('(Brookpark,OH)',),
#  ('("Brook Park",OH)',),
#  ('(Brossard,QC)',),
#  ('(Brownsburg-Chatham,QC)',),
#  ('(Brunswick,OH)',),
#  ('("Brunswick Hills",OH)',),
#  ('(Buckeye,AZ)',),
#  ('("Buckeye - Shaker",OH)',),
#  ('("Buena Vista",PA)',),
#  ('(Burlington,ON)',),
#  ('(Burton,OH)',),
#  ('(Bury,XGM)',),
#  ('(Caledon,ON)',),
#  ('("Caledon East",ON)',),
#  ('("Caledon Village",ON)',),
#  ('(calgary,AB)',),
#  ('(Calgary,AB)',),
#  ('(Calgary,AL)',),
#  ('(CALGARY,AB)',),
#  ('(Candiac,QC)',),
#  ('(Canonsburd,PA)',),
#  ('(Canonsburg,PA)',),
#  ('(Canonsburg,WA)',),
#  ('(Carefree,AZ)',),
#  ('(CAREFREE,AZ)',),
#  ('(Carnegie,PA)',),
#  ('(CARSON,PA)',),
#  ('("Castle Shannon",PA)',),
#  ('("Catawba Springs",NC)',),
#  ('("cave creek",AZ)',),
#  ('("Cave creek",AZ)',),
#  ('("Cave Creek",AZ)',),
#  ('("CAVE CREEK",AZ)',),
#  ('("Cave Creek Road",AZ)',),
#  ('(Cecil,PA)',),
#  ('("Centennial Hills",NV)',),
#  ('(Central,AZ)',),
#  ('("Central City",AZ)',),
#  ('("Central City Village",AZ)',),
#  ('("Central Henderson",NV)',),
#  ('("Central Oakland",PA)',),
#  ('("Centre Island",ON)',),
#  ('("Chagrin Falls",OH)',),
#  ('(Chambly,QC)',),
#  ('(Champaign,IL)',),
#  ('(Champlain,NY)',),
#  ('(Chander,AZ)',),
#  ('(\u200bChandler,AZ)',),
#  ('(Chandler,AL)',),
#  ('(Chandler,AZ)',),
#  ('(Chandler,CA)',),
#  ('(Chandler-Gilbert,AZ)',),
#  ('(Char,NC)',),
#  ('(Chardon,OH)',),
#  ('("Chargrin Falls",OH)',),
#  ('(Charlemagne,QC)',),
#  ('(charlotte,NC)',),
#  ('(Charlotte,NC)',),
#  ('(Charlotte,SC)',),
#  ('("Charlotte ",NC)',),
#  ('(CHARLOTTE,NC)',),
#  ('(charlottte,NC)',),
#  ('(Chatauguay,QC)',),
#  ('(Chateau,PA)',),
#  ('(Chateauguay,QC)',),
#  ('(Châteauguay,QC)',),
#  ('(Chattanooga,TN)',),
#  ('(Chertsey,QC)',),
#  ('(Chesterland,OH)',),
#  ('(Chestermere,AB)',),
#  ('(Cheswick,PA)',),
#  ('("Chomedey, Laval",QC)',),
#  ('("Church Cove",CON)',),
#  ('(Citibank,NV)',),
#  ('("City Center",NV)',),
#  ('(Clairton,PA)',),
#  ('(Claremont,ON)',),
#  ('(Clark,NV)',),
#  ('(Clarkson,ON)',),
#  ('("C Las Vegas",NV)',),
#  ('(Cleveland,OH)',),
#  ('(CLEVELAND,OH)',),
#  ('("Cleveland Heigh",OH)',),
#  ('("Cleveland Height",OH)',),
#  ('("Cleveland Heights",OH)',),
#  ('("Cleveland Hghts.",OH)',),
#  ('("Cleveland Hts.",OH)',),
#  ('("Cleveland, OH",OH)',),
#  ('(Clinton,PA)',),
#  ('(Closter,NY)',),
#  ('(Clover,SC)',),
#  ('("Columbia Sta",OH)',),
#  ('("Columbia Station",OH)',),
#  ('(Columbus,WI)',),
#  ('(Communauté-Urbaine-de-Montréal,QC)',),
#  ('(Concord,NC)',),
#  ('(Concord,OH)',),
#  ('(Concord,ON)',),
#  ('(CONCORD,NC)',),
#  ('("Concord Mills",NC)',),
#  ('("Concord Township",OH)',),
#  ('("Concord Twp",OH)',),
#  ('(Cooksville,ON)',),
#  ('(Copley,OH)',),
#  ('(Coraopolis,PA)',),
#  ('(Cornelius,NC)',),
#  ('(Coteau-du-Lac,QC)',),
#  ('("Cote Saint Luc",QC)',),
#  ('("Cote Saint-Luc",QC)',),
#  ('(Cote-Saint-Luc,QC)',),
#  ('("Côte Saint-Luc",QC)',),
#  ('(Côte-Saint-Luc,QC)',),
#  ('("Cottage Grove",WI)',),
#  ('(Crafton,PA)',),
#  ('(Cramerton,NC)',),
#  ('("Cranberry Township",PA)',),
#  ('("Cranberry Twp",PA)',),
#  ('(Creighton,PA)',),
#  ('(Crescent,PA)',),
#  ('("Cross Plains",WI)',),
#  ('(Crouse,NC)',),
#  ('(Cuddy,PA)',),
#  ('("Cuyahoga Falls",OH)',),
#  ('("Cuyahoga Fls",OH)',),
#  ('("Cuyahoga Heights",OH)',),
#  ('("Cuyohoga Falls",OH)',),
#  ('(Dallas,NC)',),
#  ('(Dallas,TX)',),
#  ('(Dane,WI)',),
#  ('(Darlington,SC)',),
#  ('(Davidson,NC)',),
#  ('(Decatur,NV)',),
#  ('(Deerfield,WI)',),
#  ('(Deforest,WI)',),
#  ('("De Forest",WI)',),
#  ('(DeForest,WI)',),
#  ('("De l\'Eglise",QC)',),
#  ('(Delson,QC)',),
#  ('(Denver,NC)',),
#  ('(DENVER,NC)',),
#  ('("Desert Ridge",AZ)',),
#  ('(Deux-Montagnes,QC)',),
#  ('("Deux-Montagnes Regional County Municipality",QC)',),
#  ('(Dewey,IL)',),
#  ('("De Winton",AB)',),
#  ('("Division No. 6",AB)',),
#  ('("Dollard-des Ormeaux",QC)',),
#  ('(Dollard-des-Ormeaux,QC)',),
#  ('("Dollard-Des Ormeaux",QC)',),
#  ('(Dollard-Des-Ormeaux,QC)',),
#  ('("Don Mills",ON)',),
#  ('(Dormont,PA)',),
#  ('(Dorval,QC)',),
#  ('(Down,DOW)',),
#  ('(Downsview,ON)',),
#  ('(Downtown,AB)',),
#  ('(Downtown,PA)',),
#  ('("Downtown Toronto",ON)',),
#  ('(Draper,UT)',),
#  ('(Dravosburg,PA)',),
#  ('(Dublin,CA)',),
#  ('(Duquesne,PA)',),
#  ('("Durham Regional Municipality",ON)',),
#  ('("East Ajax",ON)',),
#  ('("East Calgary",AB)',),
#  ('("East Cleveland",OH)',),
#  ('("East Credit",ON)',),
#  ('("East Gwilimbury",ON)',),
#  ('("East Gwillimbury",ON)',),
#  ('("East Hawkesbury",ON)',),
#  ('(Eastlake,OH)',),
#  ('("East Liberty",PA)',),
#  ('("East Mc Keesport",PA)',),
#  ('("East McKeesport",PA)',),
#  ('("East Mesa",AZ)',),
#  ('("East Mississauga",ON)',),
#  ('("East Pittsburgh",PA)',),
#  ('("East York",ON)',),
#  ('(Edgemont,AB)',),
#  ('(Edgewood,PA)',),
#  ('(Edmonton,AB)',),
#  ('("Eighty Four",PA)',),
#  ('(Elizabeth,PA)',),
#  ('("Elizabeth Township",PA)',),
#  ('("El Mirage",AZ)',),
#  ('(Elrama,PA)',),
#  ('(Elyria,OH)',),
#  ('(Emsworth,PA)',),
#  ('(Enterprise,NV)',),
#  ('(Erie,OH)',),
#  ('(Erie,PA)',),
#  ('(Estérel,QC)',),
#  ('("Estrella Village",AZ)',),
#  ('(Etibicoke,ON)',),
#  ('(Etna,PA)',),
#  ('(etobicoke,ON)',),
#  ('(Etobicoke,ON)',),
#  ('("Etobicoke,",ON)',),
#  ('(ETOBICOKE,ON)',),
#  ('(Etobiicoke,ON)',),
#  ('(Euclid,OH)',),
#  ('(Evergreen,AB)',),
#  ('(Export,PA)',),
#  ('(Fabreville,QC)',),
#  ('(Fairlawn,OH)',),
#  ('("Fairport Harbor",OH)',),
#  ('("Fairview Park",OH)',),
#  ('(Farmington,CT)',),
#  ('(Farnham,QC)',),
#  ('(Finleyville,PA)',),
#  ('(Fisher,IL)',),
#  ('(Fitchburg,WI)',),
#  ('(Fitchburgh,WI)',),
#  ('(Fithian,IL)',),
#  ('("Forest Hills",PA)',),
#  ('("Fort Mcdowell",AZ)',),
#  ('("Fort McDowell",AZ)',),
#  ('("Fort mill",SC)',),
#  ('("Fort  Mill",SC)',),
#  ('("Fort Mill",NC)',),
#  ('("Fort Mill",SC)',),
#  ('("FORT MILL",SC)',),
#  ('("Fountain Hills",AZ)',),
#  ('("Fountain Hls",AZ)',),
#  ('("Fox Chapel",PA)',),
#  ('("Franklin Park",PA)',),
#  ('(Frazer,PA)',),
#  ('("Ft. Mill",SC)',),
#  ('("Garfield Heights",OH)',),
#  ('("Garfield Hts",OH)',),
#  ('(Garrettsville,OH)',),
#  ('(Gastonia,NC)',),
#  ('(GASTONIA,NC)',),
#  ('("Gates Mills",OH)',),
#  ('(Geauga,OH)',),
#  ('(Gelndale,AZ)',),
#  ('(Georgetown,ON)',),
#  ('(Gibsonia,PA)',),
#  ('(Gifford,IL)',),
#  ('(Gilbert,AZ)',),
#  ('(Gilbert,CA)',),
#  ('(Gilbert,FL)',),
#  ('(GIlbert,AZ)',),
#  ('(GILBERT,AZ)',),
#  ('(Glassport,PA)',),
#  ('(Glbert,AZ)',),
#  ('(glendale,AZ)',),
#  ('(Glendale,AZ)',),
#  ('(Glendale,CT)',),
#  ('(GLENDALE,AZ)',),
#  ('("Glendale Az",AZ)',),
#  ('(Glenshaw,PA)',),
#  ('("Glen Williams",ON)',),
#  ('(Godmanchester,QC)',),
#  ('(Goodwood,ON)',),
#  ('(Goodyear,AZ)',),
#  ('(GOODYEAR,AZ)',),
#  ('(Gormley,ON)',),
#  ('(Grafton,OH)',),
#  ('("Grand Canyon",AZ)',),
#  ('("Grand River",OH)',),
#  ('("Greenfield Park",QC)',),
#  ('(Greensboro,NC)',),
#  ('("Green Tree",PA)',),
#  ('("Green Valley",NV)',),
#  ('(Greenway,AZ)',),
#  ('("Grove City",OH)',),
#  ('(Guadalupe,AZ)',),
#  ('("Halton Hills",ON)',),
#  ('(Hamilton,ON)',),
#  ('(Hampstead,QC)',),
#  ('("Hampton Township",PA)',),
#  ('("Harmar Township",PA)',),
#  ('(Harmarville,PA)',),
#  ('(Harrisbug,NC)',),
#  ('(Harrisburg,NC)',),
#  ('("Harrisburg,",NC)',),
#  ('("Harrison City",PA)',),
#  ('(Harwick,PA)',),
#  ('(Heidelberg,PA)',),
#  ('(Hemmingford,QC)',),
#  ('(henderson,NV)',),
#  ('(Henderson,NV)',),
#  ('(HENDERSON,NV)',),
#  ('("Henderson and Las vegas",NV)',),
#  ('("Henderson (Green Valley)",NV)',),
#  ('("Henderson Nevada",AL)',),
#  ('(Hendersonville,PA)',),
#  ('(Henderston,NV)',),
#  ('(Hendserson,NV)',),
#  ('(Henryville,QC)',),
#  ('(Herminie,PA)',),
#  ('("Highland Heights",OH)',),
#  ('("Highland Hills",OH)',),
#  ('("Highland Hts",OH)',),
#  ('("Highland Park",AB)',),
#  ('(Higley,AZ)',),
#  ('(Hinckley,OH)',),
#  ('(Hiram,OH)',),
#  ('(Hnederson,NV)',),
#  ('("Holland Landing",ON)',),
#  ('(Homer,IL)',),
#  ('(Homestead,PA)',),
#  ('(Hudson,FL)',),
#  ('(Hudson,OH)',),
#  ('(Hudson,QC)',),
#  ('(Huntersville,NC)',),
#  ('(Huntingdon,QC)',),
#  ('("Huntington Beach",CA)',),
#  ('(Huntsburg,OH)',),
#  ('("Hyland Heights",OH)',),
#  ('(Iberville,QC)',),
#  ('("Île des Soeurs",QC)',),
#  ('(Île-des-Soeurs,QC)',),
#  ('(Imperial,PA)',),
#  ('(Independence,OH)',),
#  ('("Indian land",NC)',),
#  ('("Indian land",SC)',),
#  ('("Indian Land",SC)',),
#  ('("Indian Land,",SC)',),
#  ('("INDIAN LAND",SC)',),
#  ('(Indianola,PA)',),
#  ('("Indian Trail",NC)',),
#  ('("Indian Trail",OH)',),
#  ('(Inglewood,ON)',),
#  ('(Ingomar,PA)',),
#  ('(Ingram,PA)',),
#  ('(Irwin,PA)',),
#  ('(Ivesdale,IL)',),
#  ('("Jefferson Hills",PA)',),
#  ('(Joliet,IL)',),
#  ('(Joliette,QC)',),
#  ('(Kahnawake,QC)',),
#  ('(Kannapolis,NC)',),
#  ('("Kennedy Township",PA)',),
#  ('(Kent,OH)',),
#  ('(Kettleby,ON)',),
#  ('(King,ON)',),
#  ('("King City",ON)',),
#  ('(Kirkland,QC)',),
#  ('(Kirkland,WA)',),
#  ('(kirtland,OH)',),
#  ('(Kirtland,OH)',),
#  ('(Kleinburg,ON)',),
#  ('(Lachenaie,QC)',),
#  ('(Lachine,QC)',),
#  ('(Lachute,QC)',),
#  ('(Lacolle,QC)',),
#  ('(Lagrange,OH)',),
#  ('(LaGrange,OH)',),
#  ('("Lake Las Vegas",NV)',),
#  ('("Lake Mead",NV)',),
#  ('("Lake Norman",NC)',),
#  ('("Lake Park",NC)',),
#  ('(Lakewood,OH)',),
#  ('("Lakewood, Oh",OH)',),
#  ('("Lake Wylie",SC)',),
#  ('(Lancaster,SC)',),
#  ('("La Prairie",QC)',),
#  ('(Lasalle,QC)',),
#  ('("La Salle",QC)',),
#  ('(LaSalle,QC)',),
#  ("(L'assomption,QC)",),
#  ("(L'Assomption,QC)",),
#  ('("las vegas",NV)',),
#  ('("las Vegas",NV)',),
#  ('("Las vegas",NV)',),
#  ('("Las  Vegas",NV)',),
#  ('("Las Vegas",AZ)',),
#  ('("Las Vegas",CA)',),
#  ('("Las Vegas",FL)',),
#  ('("Las Vegas",GA)',),
#  ('("Las Vegas",NC)',),
#  ('("Las Vegas",NE)',),
#  ('("Las Vegas",NM)',),
#  ('("Las Vegas",NV)',),
#  ('("Las Vegas",TX)',),
#  ('("Las Vegas ",NV)',),
#  ('("Las Vegas,",NV)',),
#  ('(LasVegas,NV)',),
#  ('("LAS VEGAS",NV)',),
#  ('("Las Vegas East",NV)',),
#  ('("Las Vegas & Henderson",NV)',),
#  ('("Las Vegas Nevada",NV)',),
#  ('("Las Vegas Nv",CA)',),
#  ('("Las Vegas NV",NV)',),
#  ('("Las Vegas, NV",NV)',),
#  ('("Las Vegass",NV)',),
#  ('("Las Vegas Valley",NV)',),
#  ('("Las Vergas",NV)',),
#  ('(Laval,QC)',),
#  ('("Laval, Pont Viau",QC)',),
#  ('("Laval, Ste Dorothee",QC)',),
#  ('(Lavaltrie,QC)',),
#  ('(Laveen,AZ)',),
#  ('(LAVEEN,AZ)',),
#  ('("Laveen Village",AZ)',),
#  ('("La Vegas",NV)',),
#  ('(Lawrence,PA)',),
#  ('(Lawrenceville,PA)',),
#  ('(Leaside,ON)',),
#  ('(Leeds,XWY)',),
#  ('(Leetsdale,PA)',),
#  ('("Le Haut-Saint-Laurent Regional County Municipality",QC)',),
#  ('("Les Cèdres",QC)',),
#  ('("Les Coteaux",QC)',),
#  ('(Leslieville,ON)',),
#  ('("Le Sud-Ouest",QC)',),
#  ('(Library,PA)',),
#  ("(L'ile-Bizard,QC)",),
#  ("(L'Île-Bizard,QC)",),
#  ("(L'ile-Perrot,QC)",),
#  ("(L'Île-Perrot,QC)",),
#  ('(Lindale,OH)',),
#  ('(Litchfield,AZ)',),
#  ('(Litchfield,CT)',),
#  ('(Litchfield,OH)',),
#  ('("Litchfield park",AZ)',),
#  ('("Litchfield Park",AZ)',),
#  ('(Locust,NC)',),
#  ('(Lodi,WI)',),
#  ('(London,XGL)',),
#  ('(Longueuil,QC)',),
#  ('(Lorain,OH)',),
#  ('("Los Angeles",CA)',),
#  ('("Los Vegas",NV)',),
#  ('(Lowell,NC)',),
#  ('("Lower burrell",PA)',),
#  ('("Lower Burrell",PA)',),
#  ('("Lower Lawrenceville",PA)',),
#  ('(Lowesville,NC)',),
#  ('(Lufkin,TX)',),
#  ('(lyndhurst,OH)',),
#  ('(Lyndhurst,OH)',),
#  ('(Lynhurst,OH)',),
#  ('(Macedonia,OH)',),
#  ('(MACEDONIA,OH)',),
#  ('(Madison,OH)',),
#  ('(Madison,WI)',),
#  ('(MADISON,WI)',),
#  ('(Mahomet,IL)',),
#  ('(Malton,ON)',),
#  ('(Manchester,XGM)',),
#  ('(Mansfield,IL)',),
#  ('(Mantua,OH)',),
#  ('(Maple,ON)',),
#  ('("Maple Grove",QC)',),
#  ('("Maple Heights",OH)',),
#  ('(Maricopa,AZ)',),
#  ('(markham,ON)',),
#  ('(Markham,ON)',),
#  ('("Markham, ON",ON)',),
#  ('(Marshall,WI)',),
#  ('(Marvin,NC)',),
#  ('(Mascouche,QC)',),
#  ('(Mathews,NC)',),
#  ('(Mattews,NC)',),
#  ('(Matthews,NC)',),
#  ('(MATTHEWS,NC)',),
#  ('(Mayfield,OH)',),
#  ('("Mayfield Heights",OH)',),
#  ('("Mayfield Heights.",OH)',),
#  ('("Mayfield Heights (Cleveland)",OH)',),
#  ('("Mayfield Hts",OH)',),
#  ('("Mayfield Hts.",OH)',),
#  ('("Mayfield Village",OH)',),
#  ('("Mc Adenville",NC)',),
#  ('(McAdenville,NC)',),
#  ('(McCandless,PA)',),
#  ('("Mccandless Township",PA)',),
#  ('("McCandless Township",PA)',),
#  ('(Mcdonald,PA)',),
#  ('("Mc Donald",PA)',),
#  ('(McDonald,PA)',),
#  ('(Mcfarland,WI)',),
#  ('("Mc Farland",WI)',),
#  ('(McFarland,WI)',),
#  ('(Mckeesport,PA)',),
#  ('(McKeesport,PA)',),
#  ('("Mckees Rocks",PA)',),
#  ('("Mc Kees Rocks",PA)',),
#  ('("McKees Rocks",PA)',),
#  ('(McKeesRocks,PA)',),
#  ('(Mcknight,PA)',),
#  ('(McKnight,PA)',),
#  ('(McMasterville,QC)',),
#  ('(Mcmurray,PA)',),
#  ('("Mc Murray",PA)',),
#  ('(McMurray,PA)',),
#  ('(McMurry,PA)',),
#  ('(Median,OH)',),
#  ('("Medicine Hat",AB)',),
#  ('(Medina,OH)',),
#  ('("Medina Township",OH)',),
#  ('(Mentor,OH)',),
#  ('("Mentor On the",OH)',),
#  ('(Mentor-on-the-Lake,OH)',),
#  ('("Mentor On the Lake",OH)',),
#  ('("Mentor On The Lake",OH)',),
#  ('(Mentor-On-The-Lake,OH)',),
#  ('(Mercier,QC)',),
#  ('(mesa,AZ)',),
#  ('(Mesa,AZ)',),
#  ('(MESA,AZ)',),
#  ('("Mesa Arizona",AZ)',),
#  ('("Mesa AZ",AZ)',),
#  ('("Metro Phoenix",AZ)',),
#  ('(Middleburg,OH)',),
#  ('("Middleburg Heights",OH)',),
#  ('("Middleburg Hts",OH)',),
#  ('("Middleburg Hts.",OH)',),
#  ('(Middlefield,OH)',),
#  ('(Middleton,WI)',),
#  ('(Midland,NC)',),
#  ('(Midnapore,AB)',),
#  ('(Midway,PA)',),
#  ('(Milford,OH)',),
#  ('(Millvale,PA)',),
#  ('(Milton,ON)',),
#  ('("Mint  Hill",NC)',),
#  ('("Mint Hill",NC)',),
#  ('(Mirabel,QC)',),
#  ('(Missisauga,ON)',),
#  ('(Mississagua,ON)',),
#  ('(Mississauaga,ON)',),
#  ('(Mississauga,ON)',),
#  ('(Mississauge,ON)',),
#  ('(Mississaugua,ON)',),
#  ('(Mississuaga,ON)',),
#  ('(Monona,WI)',),
#  ('(Monongahela,PA)',),
#  ('(Monoroeville,PA)',),
#  ('(Monreoville,PA)',),
#  ('(Monroe,NC)',),
#  ('(Monroeville,PA)',),
#  ('(MONROEVILLE,PA)',),
#  ('(Montéal,QC)',),
#  ('("Monterey Park",CA)',),
#  ('(Montgomery,NC)',),
#  ('(Monticello,AR)',),
#  ('(Monticello,IL)',),
#  ('(Montral,QC)',),
#  ('(montreal,QC)',),
#  ('(Montreal,AB)',),
#  ('(Montreal,QC)',),
#  ('(Montréal,QC)',),
#  ('(Montrèal,QC)',),
#  ('(Montreal-Est,QC)',),
#  ('(Montréal-Est,QC)',),
#  ('(Montreal-Nord,QC)',),
#  ('(Montréal-Nord,QC)',),
#  ('(Montreal-Ouest,QC)',),
#  ('(Montréal-Ouest,QC)',),
#  ('("Montréal (Québec)",QC)',),
#  ('(Montreal-Quest,QC)',),
#  ('(Montreal-West,QC)',),
#  ('(Montréal-West,QC)',),
#  ('(Montrose,OH)',),
#  ('(Mont-Royal,QC)',),
#  ('(Mont-Saint-Grégoire,QC)',),
#  ('(Mont-Saint-Hilaire,QC)',),
#  ('("Mont St-hilaire",QC)',),
#  ('(Montville,OH)',),
#  ('(Mooers,NY)',),
#  ('(moon,PA)',),
#  ('(Moon,PA)',),
#  ('("Moon Township",PA)',),
#  ('("Moon Twp",PA)',),
#  ('("Moon Twp.",PA)',),
#  ('("Moon TWP",PA)',),
#  ('(Mooresville,NC)',),
#  ('("Moreland Hills",OH)',),
#  ('(Morgan,PA)',),
#  ('("Morgan Hill",CA)',),
#  ('(Morin-Heights,QC)',),
#  ('(Moseley,VA)',),
#  ('("Mount Albert",ON)',),
#  ('("Mount Holly",NC)',),
#  ('("Mount Horeb",WI)',),
#  ('("Mount Lebanon",PA)',),
#  ('("Mount Oliver",PA)',),
#  ('("Mount Washington",PA)',),
#  ('("Mt Holly",NC)',),
#  ('("Mt. Holly",NC)',),
#  ('("Mt. Horeb",WI)',),
#  ('("Mt Lebanon",PA)',),
#  ('("Mt. Lebanon",PA)',),
#  ('("Mt. Washington",PA)',),
#  ('(Munhall,PA)',),
#  ('("Munroe Falls",OH)',),
#  ('(Murrysville,PA)',),
#  ('("Murrysville (Monroeville)",PA)',),
#  ('(Napierville,QC)',),
#  ('(Nationwide,CA)',),
#  ('("N E Las Vegas",NV)',),
#  ('(Nellis,NV)',),
#  ('("Nellis Afb",NV)',),
#  ('("Nellis AFB",NV)',),
#  ('("NELLIS AFB",NV)',),
#  ('("Nellis Air Force Base",NV)',),
#  ('(Nevada,NV)',),
#  ('("Neville Island",PA)',),
#  ('("Newburgh Heights",OH)',),
#  ('(Newbury,OH)',),
#  ('("New Eagle",PA)',),
#  ('("New Glarus",WI)',),
#  ('("New Kensington",PA)',),
#  ('(Newmarket,ON)',),
#  ('(NEWMARKET,ON)',),
#  ('("New River",AZ)',),
#  ('("New Tecumseth",ON)',),
#  ('("New York",NY)',),
#  ('("N Las Vegas",NV)',),
#  ('("N. Las Vegas",NV)',),
#  ('(Nobleton,ON)',),
#  ('("N. Olmsted",OH)',),
#  ('("North Braddock",PA)',),
#  ('("North Carolina",NC)',),
#  ('("North Charlotte",NC)',),
#  ('("Northeast Calgary",AB)',),
#  ('(Northfield,OH)',),
#  ('("Northfield Center",OH)',),
#  ('("Northfield Center Township",OH)',),
#  ('("North Hills",PA)',),
#  ('("North Huntingdon",PA)',),
#  ('("North Huntington",PA)',),
#  ('("North Las Vegas",NV)',),
#  ('("North Las Vegas",NY)',),
#  ('("North Las Vegas ",NV)',),
#  ('("NORTH LAS VEGAS",NV)',),
#  ('("North of Brampton",ON)',),
#  ('("North Olmstead",OH)',),
#  ('("North Olmsted",OH)',),
#  ('("North Olmsted,",OH)',),
#  ('("North Phoenix",AZ)',),
#  ('("North Randall",OH)',),
#  ('("North  Ridgeville",OH)',),
#  ('("North Ridgeville",OH)',),
#  ('("North Royalton",OH)',),
#  ('("North Scottsdale",AZ)',),
#  ('("North Strabane Township",PA)',),
#  ('("North Toronto",ON)',),
#  ('("North Versailles",PA)',),
#  ('("Northwest Calgary",AB)',),
#  ('("North york",ON)',),
#  ('(Northyork,ON)',),
#  ('("North  York",ON)',),
#  ('("North York",AB)',),
#  ('("North York",ON)',),
#  ('(NorthYork,ON)',),
#  ('("NORTH YORK",ON)',),
#  ('(Norton,OH)',),
#  ('(Norval,ON)',),
#  ("(Notre-Dame-de-l'Ile-Perrot,QC)",),
#  ("(Notre-Dame-De-L'ile-Perrot,QC)",),
#  ('("Nottingham Township",PA)',),
#  ('(Novelty,OH)',),
#  ('(Noyan,QC)',),
#  ('("N. Randall",OH)',),
#  ('("N Ridgeville",OH)',),
#  ('("N. Ridgeville",OH)',),
#  ('("N Solon",OH)',),
#  ('("N W Las Vegas",NV)',),
#  ('(Oakdale,PA)',),
#  ('(Oakland,PA)',),
#  ('(Oakmont,PA)',),
#  ('(Oakridges,ON)',),
#  ('("Oak Ridges",ON)',),
#  ('(oakville,ON)',),
#  ('(Oakville,ON)',),
#  ('(Oakwood,OH)',),
#  ('("Oakwood village",OH)',),
#  ('("Oakwood Village",OH)',),
#  ('(Oberlin,OH)',),
#  ('(Ogden,IL)',),
#  ('("O\'hara Township",PA)',),
#  ('(Oka,QC)',),
#  ('("Old Brooklyn",OH)',),
#  ('(Oldham,XGM)',),
#  ('("Old Port of Montreal",QC)',),
#  ('("Old Scottsdale",AZ)',),
#  ('("Old Town Scottsdale",AZ)',),
#  ('("Olmsted Falls",OH)',),
#  ('("Olmsted Township",OH)',),
#  ('(Omaha,NE)',),
#  ('(Orange,OH)',),
#  ('("Orange Village",OH)',),
#  ('(Oregon,WI)',),
#  ('(Ormstown,QC)',),
#  ('(Oshawa,ON)',),
#  ('("Otterburn Park",QC)',),
#  ('(Outremont,QC)',),
#  ('(Pahrump,NV)',),
#  ('(Painesville,OH)',),
#  ('("Painesville Township",OH)',),
#  ('(Palgrave,ON)',),
#  ('(Paoli,WI)',),
#  ('(Paradise,NV)',),
#  ('("Paradise Valley",AZ)',),
#  ('(Parma,OH)',),
#  ('("Parma Heights",OH)',),
#  ('("PARMA HEIGHTS",OH)',),
#  ('("Parma mid birth",OH)',),
#  ('(Pasadena,AZ)',),
#  ('("Paw Creek",NC)',),
#  ('(Peninsul,OH)',),
#  ('(Peninsula,CA)',),
#  ('(Peninsula,OH)',),
#  ('("Penn Hills",PA)',),
#  ('("Penn Hills Township",PA)',),
#  ('(Pennsylvania,PA)',),
#  ('(peoria,AZ)',),
#  ('(Peoria,AZ)',),
#  ('(PEORIA,AZ)',),
#  ('(Pepperpike,OH)',),
#  ('("Pepper Pike",OH)',),
#  ('(Perry,OH)',),
#  ('("Perry Twp",OH)',),
#  ('("Peters Township",PA)',),
#  ('("Pgh Int Arprt",PA)',),
#  ('(Pheonix,AZ)',),
#  ('("Pheonix AZ",AZ)',),
#  ('(Philo,IL)',),
#  ('(Phoeniix,AZ)',),
#  ('(phoenix,AZ)',),
#  ('(Phoenix,AZ)',),
#  ('(Phoenix,TX)',),
#  ('("Phoenix ",AZ)',),
#  ('("Phoenix,",AZ)',),
#  ('(PHOENIX,AZ)',),
#  ('("Phoenix AZ",AZ)',),
#  ('("Phoenix, AZ",AZ)',),
#  ('("Phoenix Metro Area",AZ)',),
#  ('("Phoenix Valley",AZ)',),
#  ('(Phoenx,AZ)',),
#  ('(Phoneix,AZ)',),
#  ('(Phoniex,AZ)',),
#  ('(Phx,AZ)',),
#  ('(Pickering,ON)',),
#  ('("Pickering Ajax Whitby",ON)',),
#  ('(Piedmont,QC)',),
#  ('(Pierrefonds,QC)',),
#  ('(Pincourt,QC)',),
#  ('(Pine,PA)',),
#  ('(Pineville,NC)',),
#  ('(Pitcairn,PA)',),
#  ('(Pittsburch,PA)',),
#  ('(Pittsburg,PA)',),
#  ('(Pittsburgh,PA)',),
#  ('(Pittsburgh,VA)',),
#  ('("Pittsburgh ",PA)',),
#  ('("Pleasant Hills",PA)',),
#  ('(Plum,PA)',),
#  ('("Plum Boro",PA)',),
#  ('(Point-Claire,QC)',),
#  ('(Pointe-aux-Trembles,QC)',),
#  ('(Pointe-Aux-Trembles,QC)',),
#  ('(Pointe-Calumet,QC)',),
#  ('("Pointe Claire",QC)',),
#  ('(Pointe-Claire,QC)',),
#  ('("Port Credit",ON)',),
#  ('("Port Vue",PA)',),
#  ('(Presto,PA)',),
#  ('(Prévost,QC)',),
#  ('(Promenade,NC)',),
#  ('(Puyallup,WA)',),
#  ('("Quartier des Spectacles",QC)',),
#  ('(Québec,QC)',),
#  ('("Queen creek",AZ)',),
#  ('("Queen Creek",AK)',),
#  ('("Queen Creek",AZ)',),
#  ('("QUEEN CREEK",AZ)',),
#  ('(Queensville,ON)',),
#  ('("Rainbow Valley",AZ)',),
#  ('(Rankin,PA)',),
#  ('(Ranlo,NC)',),
#  ('(Rantoul,IL)',),
#  ('(Ravenna,OH)',),
#  ('(Rawdon,QC)',),
#  ('("Red Mountain",AZ)',),
#  ('("Red Rock",AZ)',),
#  ('("Regent Square",PA)',),
#  ('("Regional Municipality of York",ON)',),
#  ('(Reminderville,OH)',),
#  ('(Repentigny,QC)',),
#  ('(Rexdale,ON)',),
#  ('(Richfield,OH)',),
#  ('("Richland Township",PA)',),
#  ('("Richmond Height",OH)',),
#  ('("Richmond Heights",OH)',),
#  ('("Richmond Hil",ON)',),
#  ('("Richmond Hill",BC)',),
#  ('("Richmond Hill",ON)',),
#  ('("RIchmond Hill",ON)',),
#  ('("Richmond Hts",OH)',),
#  ('(Richmonhill,ON)',),
#  ('(Rigaud,QC)',),
#  ('(Rillton,PA)',),
#  ('("Rio Verde",AZ)',),
#  ('("River Drive Park",ON)',),
#  ('(Robinson,PA)',),
#  ('("Robinson Township",PA)',),
#  ('("Robinson Twp.",PA)',),
#  ('("Rockey View",AB)',),
#  ('("Rock Hill",SC)',),
#  ('("Rock Hill SC",SC)',),
#  ('("Rocky river",OH)',),
#  ('("Rocky River",OH)',),
#  ('(Rockyview,AB)',),
#  ('("Rocky View",AB)',),
#  ('("Rockyview County",AB)',),
#  ('("Rocky View County",AB)',),
#  ('("Rocky View No. 44",AB)',),
#  ('(Rosemere,QC)',),
#  ('(Rosemère,QC)',),
#  ('(Ross,PA)',),
#  ('("Ross Township",PA)',),
#  ('(Rostraver,PA)',),
#  ('(Rougemont,QC)',),
#  ('("Rouses Point",NY)',),
#  ('(Roxboro,QC)',),
#  ('("Rural Ridge",PA)',),
#  ('(Russellton,PA)',),
#  ('("Russell Twp",OH)',),
#  ('(Sacramento,CA)',),
#  ('("Sagamore Hills",OH)',),
#  ('("Sage Hill",AB)',),
#  ('(Saint-Basile-le-Grand,QC)',),
#  ('(Saint-Basile-Le-Grand,QC)',),
#  ('("Saint-Bernard de Lacolle",QC)',),
#  ('(Saint-Bernard-de-Lacolle,QC)',),
#  ('(Saint-Bruno,QC)',),
#  ('(Saint-Bruno-de-Montarville,QC)',),
#  ('(Saint-Charles-Borromee,QC)',),
#  ('(Saint-Constant,QC)',),
#  ('(Sainte-Adele,QC)',),
#  ('(Sainte-Adèle,AB)',),
#  ('(Sainte-Adèle,QC)',),
#  ('(Sainte-Anne-de-Bellevue,QC)',),
#  ('(Sainte-Anne-De-Bellevue,QC)',),
#  ('(Sainte-Anne-des-Plaines,QC)',),
#  ('(Sainte-Catherine,QC)',),
#  ('(Sainte-Dorothée,QC)',),
#  ('(Sainte-Genevieve,QC)',),
#  ('(Sainte-Geneviève,QC)',),
#  ('(Sainte-Julie,QC)',),
#  ('(Sainte-Madeleine,QC)',),
#  ('(Sainte-Marguerite-du-lac-Masson,QC)',),
#  ('(Sainte-Marguerite-du-Lac-Masson,QC)',),
#  ('(Sainte-Marguerite-Esterel,QC)',),
#  ('(Sainte-Marthe,QC)',),
#  ('(Sainte-Rose,QC)',),
#  ('(Sainte-Therese,QC)',),
#  ('(Sainte-thérèse,QC)',),
#  ('(Sainte-Thérèse,QC)',),
#  ('(Sainte-Thérèse-de-Blainville,QC)',),
#  ('(Saint-Eustache,QC)',),
#  ('(Saint-Henri,QC)',),
#  ('(Saint-Hippolyte,QC)',),
#  ('(Saint-Hubert,QC)',),
#  ('("Saint - Hyacinthe",QC)',),
#  ('(Saint-Hyacinthe,QC)',),
#  ('(Saint-Isidore-de-Laprairie,QC)',),
#  ('(Saint-Jean-sur-Richelieu,QC)',),
#  ('(Saint-Jean-Sur-Richelieu,QC)',),
#  ('(Saint-Jerome,QC)',),
#  ('(Saint-Jérôme,QC)',),
#  ('("Saint Joseph",IL)',),
#  ('(Saint-Lambert,QC)',),
#  ('(Saint-laurent,QC)',),
#  ('("Saint Laurent",QC)',),
#  ('(Saint-Laurent,QC)',),
#  ('(Saint-Lazare,QC)',),
#  ('("Saint Leonard",QC)',),
#  ('(Saint-Leonard,QC)',),
#  ('(Saint-Léonard,QC)',),
#  ('(Saint-Marc-sur-Richelieu,QC)',),
#  ('(Saint-Philippe,QC)',),
#  ('(Saint-Pie,QC)',),
#  ('(Saint-Pierre-de-Véronne-à-Pike-River,QC)',),
#  ("(Saint-Roch-de-l'Achigan,QC)",),
#  ('(Saint-Sauveur,QC)',),
#  ('(Saint-Sauveur-des-Monts,QC)',),
#  ('(Saintt-Bruno-de-Montarville,QC)',),
#  ('(Salaberry-de-Valleyfield,QC)',),
#  ('(Salaberry-De-Valleyfield,QC)',),
#  ('(Sale,XGM)',),
#  ('("San Diego",CA)',),
#  ('("Sandy Ridge",NC)',),
#  ('("San Tan",AZ)',),
#  ('("San Tan Valley",AZ)',),
#  ('("Sauk City",WI)',),
#  ('(Savoy,IL)',),
#  ('(Scarborough,ON)',),
#  ('(SCARBOROUGH,ON)',),
#  ('(Scarbrough,ON)',),
#  ('(Scarobrough,ON)',),
#  ('(Schaumburg,IL)',),
#  ('(Schomberg,ON)',),
#  ('(Schottsdale,AZ)',),
#  ('("S Concord",NC)',),
#  ('(Scotesdale,AZ)',),
#  ('(Scotsdale,AZ)',),
#  ('(Scottadale,CA)',),
#  ('(Scottdale,AZ)',),
#  ('(Scottsale,AZ)',),
#  ('(scottsdale,AZ)',),
#  ('(Scottsdale,AZ)',),
#  ('(SCOTTSDALE,AZ)',),
#  ('("Scottsdale, AZ",AZ)',),
#  ('(Seattle,WI)',),
#  ('(Sedona,AZ)',),
#  ('("Seven Hills",NV)',),
#  ('("Seven Hills",OH)',),
#  ('(Sewickley,PA)',),
#  ('(Shadyside,PA)',),
#  ('("Shady Side",PA)',),
#  ('("Shaker Heights",OH)',),
#  ('("Shaker Hts",OH)',),
#  ('(Shaler,PA)',),
#  ('("Shaler Township",PA)',),
#  ('(Sharon,ON)',),
#  ('(Sharpsburg,PA)',),
#  ('(Sheffield,OH)',),
#  ('("Sheffield Lake",OH)',),
#  ('("Sheffield Village",OH)',),
#  ('("Shorewood Hills",WI)',),
#  ('("Side Slopes",PA)',),
#  ('(Sidney,IL)',),
#  ('("Silver Lake",OH)',),
#  ('(Snowflake,AZ)',),
#  ('(solon,OH)',),
#  ('(Solon,OH)',),
#  ('(Somerton,AZ)',),
#  ('("South Amherst",OH)',),
#  ('("South Charlotte",NC)',),
#  ('("Southeast Calgary",AB)',),
#  ('("south Euclid",OH)',),
#  ('("South Euclid",OH)',),
#  ('("South Hills",PA)',),
#  ('("South Las Vegas",NV)',),
#  ('("South Park",PA)',),
#  ('("South Park Township",PA)',),
#  ('("South Russell",OH)',),
#  ('("Southside Flats",PA)',),
#  ('(Spartanburg,SC)',),
#  ('(springdale,PA)',),
#  ('(Springdale,PA)',),
#  ('("Spring Hill City View",PA)',),
#  ('("Spring Valley",NV)',),
#  ('("Squirrel Hill",PA)',),
#  ('(Stallings,NC)',),
#  ('(Stanley,NC)',),
#  ('("St-Benoît de Mirabel",QC)',),
#  ('(St-Bruno-de-Montarville,QC)',),
#  ('(St-Clet,QC)',),
#  ('(Ste-Dorothée,QC)',),
#  ('(Ste-Rose,QC)',),
#  ('(Ste-Therese-de-Blainville,QC)',),
#  ('("Stetson Valley",AZ)',),
#  ('(St-Jean-sur-Richelieu,QC)',),
#  ('("St. Jean Sur Richelieu",QC)',),
#  ('(St-Jerome,QC)',),
#  ('("St Joseph",IL)',),
#  ('("St. Joseph",IL)',),
#  ('(St-Laurent,QC)',),
#  ('(St-Lazare,QC)',),
#  ('("St Leonard",QC)',),
#  ('(St-Leonard,QC)',),
#  ('("St. Leonard",QC)',),
#  ('("St. Léonard",QC)',),
#  ('(Stouffville,ON)',),
#  ('(Stoughton,WI)',),
#  ('(Stow,OH)',),
#  ('(St.Pittsburgh,PA)',),
#  ('(Streetsboro,OH)',),
#  ('(Streetsville,ON)',),
#  ('("Strip District",PA)',),
#  ('(Strongsville,OH)',),
#  ('(Strongville,OH)',),
#  ('("St. Sauveur",QC)',),
#  ('(Sturgeon,PA)',),
#  ('(Summerlin,NV)',),
#  ('("Summerlin South",NV)',),
#  ('(Suncity,AZ)',),
#  ('("Sun City",AZ)',),
#  ('("Sun CIty",AZ)',),
#  ('("Sun City West",AZ)',),
#  ('("Sun Lakes",AZ)',),
#  ('(Sunnyslope,AZ)',),
#  ('("Sun Praiie",WI)',),
#  ('("Sun Prairie",WI)',),
#  ('("SUN PRAIRIE",WI)',),
#  ('(Sunrise,NV)',),
#  ('("Sunrise Manor",NV)',),
#  ('(Suprise,AZ)',),
#  ('(surprise,AZ)',),
#  ('(Surprise,AZ)',),
#  ('(Surprise,CA)',),
#  ('(SURPRISE,AZ)',),
#  ('("Surprise Crossing",AZ)',),
#  ('(Sutersville,PA)',),
#  ('("SW Calgary",AB)',),
#  ('(Swissvale,PA)',),
#  ('(Tallmadge,OH)',),
#  ('(Tampa,FL)',),
#  ('(Tarentum,PA)',),
#  ('("Tega Cay",SC)',),
#  ('(Temecula,CA)',),
#  ('(tempe,AZ)',),
#  ('(Tempe,AZ)',),
#  ('("Tempe ",AZ)',),
#  ('(TEMPE,AZ)',),
#  ('(Terrebonne,QC)',),
#  ('("The Promenade",AZ)',),
#  ('(Thomasboro,IL)',),
#  ('("Thorncliffe Park",ON)',),
#  ('(Thornhil,ON)',),
#  ('(Thornhill,DUR)',),
#  ('(Thornhill,ON)',),
#  ('(THORNHILL,ON)',),
#  ('(Tolleson,AZ)',),
#  ('(TOLLESON,AZ)',),
#  ('(Tolono,IL)',),
#  ('(Tornto,ON)',),
#  ('(toronto,ON)',),
#  ('(Toronto,AB)',),
#  ('(Toronto,OH)',),
#  ('(Toronto,ON)',),
#  ('(TORONTO,ON)',),
#  ('("Toronto Division",ON)',),
#  ('(Toronto-Etobicoke,ON)',),
#  ('("Toronto-North York",ON)',),
#  ('("Toronto Scarborough",ON)',),
#  ('(Toronto-West,ON)',),
#  ('(Tottenham,ON)',),
#  ('("Township of Concord",OH)',),
#  ('(Trafford,PA)',),
#  ('(Tremont,OH)',),
#  ('("Troy Township",OH)',),
#  ('(Tucson,AZ)',),
#  ('("Turtle Creek",PA)',),
#  ('(Tuscola,IL)',),
#  ('(Twinsburg,OH)',),
#  ('(Twinsburgh,OH)',),
#  ('(Union,NJ)',),
#  ('(Unionville,ON)',),
#  ('(University,NC)',),
#  ('("University Heights",OH)',),
#  ('("University Ht",OH)',),
#  ('("University Hts ",OH)',),
#  ('("Upper Saint Clair",PA)',),
#  ('("Upper St Clair",PA)',),
#  ('("Upper St. Clair",PA)',),
#  ('(Uptown,OH)',),
#  ('(Urbana,IL)',),
#  ('("Urbana, Illinois",IL)',),
#  ('(Uxbridge,ON)',),
#  ('(Valencia,PA)',),
#  ('("Valley City",OH)',),
#  ('("Valley View",OH)',),
#  ('(Valleywide,AZ)',),
#  ('(Val-Morin,QC)',),
#  ('(Varennes,QC)',),
#  ('(Vaudreuil,QC)',),
#  ('(Vaudreuil-Dorion,QC)',),
#  ('(Vaughan,ON)',),
#  ('("Vaughan Mills",ON)',),
#  ('(Vaughn,ON)',),
#  ('(Vegas,NV)',),
#  ('(Venetia,PA)',),
#  ('(Venise-en-Québec,QC)',),
#  ('(verdun,QC)',),
#  ('(Verdun,QC)',),
#  ('(Verona,PA)',),
#  ('(Verona,WI)',),
#  ('(Vieux-Montréal,QC)',),
#  ('("Villa Grove",IL)',),
#  ('("Ville Mont-Royal",QC)',),
#  ('("Ville Saint Laurent",QC)',),
#  ('(Vimont,QC)',),
#  ('(Waddell,AZ)',),
#  ('(Wadsworth,OH)',),
#  ('("Walton Hills",OH)',),
#  ('(Warrendale,PA)',),
#  ('(Warrensville,OH)',),
#  ('("Warrensville Heights",OH)',),
#  ('("Warrensville Hts",OH)',),
#  ('("Warrensville Hts.",OH)',),
#  ('(Warrenville,OH)',),
#  ('(Waterloo,ON)',),
#  ('(Waunakee,WI)',),
#  ('(Waxhaw,NC)',),
#  ('(Weddington,NC)',),
#  ('(Wellington,OH)',),
#  ('("Wesley Chapel",NC)',),
#  ('("West Elizabeth",PA)',),
#  ('("West Homestead",PA)',),
#  ('(Westlake,OH)',),
#  ('("West Lake",OH)',),
#  ('("West Mifflin",PA)',),
#  ('("West Montréal",QC)',),
#  ('(Westmount,QC)',),
#  ('(Weston,ON)',),
#  ('(Westport,NC)',),
#  ('("West Toronto",ON)',),
#  ('(Westview,PA)',),
#  ('("West View",PA)',),
#  ('("Westworld Scottsdale",AZ)',),
#  ('(Wexford,PA)',),
#  ('("W Henderson",NV)',),
#  ('(Whiitby,ON)',),
#  ('(Whitby,ON)',),
#  ('(Whitchurch-Stouffville,ON)',),
#  ('("White Oak",PA)',),
#  ('(Whitney,NV)',),
#  ('(Whtiby,ON)',),
#  ('(Wickliffe,OH)',),
#  ('(Wildwood,PA)',),
#  ('("Wilkens Township",PA)',),
#  ('(Wilkinsburg,PA)',),
#  ('("Wilkins Township",PA)',),
#  ('(Willoughby,OH)',),
#  ('("Willoughby Hills",OH)',),
#  ('(Willowdale,ON)',),
#  ('(Willowick,OH)',),
#  ('(Wilmerding,PA)',),
#  ('(Windsor,WI)',),
#  ('(Woodbridge,ON)',),
#  ('("Woodbridge (Vaughan)",ON)',),
#  ('(Woodmere,OH)',),
#  ('("Woodmere Village",OH)',),
#  ('("W Spring Valley",NV)',),
#  ('(York,ON)',),
#  ('(York,SC)',),
#  ('(Yorkdale,ON)',),
#  ('("York Regional Municipality",ON)',),
#  ('(Yorkville,ON)',),
#  ('(Youngtown,AZ)',),
#  ('(Zephyr,ON)',)]

# %%
# How many users made reviews by city?

# cur.execute("""
#     SELECT business.city, business.state, review.user_id
# """)

# How many reviews per city?

cur.execute("""
    SELECT city, state, SUM(review_count)
    FROM business
    GROUP BY city, state
    ORDER BY SUM(review_count) DESC;
""")
print('Reviews in each city:')
pprint(cur.fetchall())

# How many restaurants in each city?

# How many resturant reviews in each city?
# Out:
# Reviews in each city:
# [('Las Vegas', 'NV', 1964943),
#  ('Phoenix', 'AZ', 706730),
#  ('Toronto', 'ON', 510842),
#  ('Scottsdale', 'AZ', 372805),
#  ('Charlotte', 'NC', 299214),
#  ('Pittsburgh', 'PA', 218769),
#  ('Henderson', 'NV', 210596),
#  ('Tempe', 'AZ', 195082),
#  ('Mesa', 'AZ', 161847),
#  ('Chandler', 'AZ', 151181),
#  ('Montréal', 'QC', 148604),
#  ('Gilbert', 'AZ', 123933),
#  ('Cleveland', 'OH', 110872),
#  ('Madison', 'WI', 101529),
#  ('Glendale', 'AZ', 96375),
#  ('Calgary', 'AB', 94827),
#  ('Peoria', 'AZ', 55392),
#  ('Mississauga', 'ON', 53711),
#  ('Markham', 'ON', 49568),
#  ('North Las Vegas', 'NV', 48944),
#  ('Surprise', 'AZ', 33246),
#  ('Champaign', 'IL', 29951),
#  ('Goodyear', 'AZ', 27303),
#  ('Richmond Hill', 'ON', 23419),
#  ('Avondale', 'AZ', 21165),
#  ('North York', 'ON', 19653),
#  ('Scarborough', 'ON', 18438),
#  ('Lakewood', 'OH', 17569),
#  ('Concord', 'NC', 16150),
#  ('Vaughan', 'ON', 15570),
#  ('Huntersville', 'NC', 15010),
#  ('Matthews', 'NC', 14814),
#  ('Etobicoke', 'ON', 12285),
#  ('Cave Creek', 'AZ', 12066),
#  ('Brampton', 'ON', 11945),
#  ('Fort Mill', 'SC', 11194),
#  ('Cornelius', 'NC', 8927),
#  ('Akron', 'OH', 8919),
#  ('Boulder City', 'NV', 8711),
#  ('Westlake', 'OH', 8629),
#  ('Urbana', 'IL', 8471),
#  ('Thornhill', 'ON', 8348),
#  ('Middleton', 'WI', 8268),
#  ('Cleveland Heights', 'OH', 8149),
#  ('Gastonia', 'NC', 7022),
#  ('Strongsville', 'OH', 6998),
#  ('Pineville', 'NC', 6846),
#  ('Fountain Hills', 'AZ', 6825),
#  ('Litchfield Park', 'AZ', 6737),
#  ('Mentor', 'OH', 6549),
#  ('Rocky River', 'OH', 6442),
#  ('North Olmsted', 'OH', 6401),
#  ('Cuyahoga Falls', 'OH', 6337),
#  ('Monroeville', 'PA', 6333),
#  ('Parma', 'OH', 5638),
#  ('Beachwood', 'OH', 5522),
#  ('Paradise Valley', 'AZ', 5118),
#  ('Rock Hill', 'SC', 5069),
#  ('Kent', 'OH', 4889),
#  ('Medina', 'OH', 4687),
#  ('Montreal', 'QC', 4637),
#  ('Oakville', 'ON', 4348),
#  ('Fitchburg', 'WI', 4302),
#  ('Independence', 'OH', 4243),
#  ('Wexford', 'PA', 4228),
#  ('Solon', 'OH', 4141),
#  ('Newmarket', 'ON', 4098),
#  ('Willoughby', 'OH', 4087),
#  ('Sun Prairie', 'WI', 3989),
#  ('Indian Trail', 'NC', 3975),
#  ('Avon', 'OH', 3916),
#  ('Hudson', 'OH', 3791),
#  ('Pickering', 'ON', 3559),
#  ('Homestead', 'PA', 3554),
#  ('Bridgeville', 'PA', 3482),
#  ('Laval', 'QC', 3455),
#  ('Sun City', 'AZ', 3450),
#  ('Stow', 'OH', 3360),
#  ('Chagrin Falls', 'OH', 3337),
#  ('Davidson', 'NC', 3322),
#  ('Belmont', 'NC', 3309),
#  ('Ajax', 'ON', 3190),
#  ('Queen Creek', 'AZ', 3127),
#  ('Woodmere', 'OH', 3077),
#  ('Tolleson', 'AZ', 3009),
#  ('Coraopolis', 'PA', 2965),
#  ('Lyndhurst', 'OH', 2933),
#  ('Laveen', 'AZ', 2903),
#  ('Woodbridge', 'ON', 2889),
#  ('Aurora', 'ON', 2827),
#  ('Whitby', 'ON', 2737),
#  ('Bethel Park', 'PA', 2660),
#  ('Waxhaw', 'NC', 2657),
#  ('Fairlawn', 'OH', 2656),
#  ('Mayfield Heights', 'OH', 2586),
#  ('Fairview Park', 'OH', 2433),
#  ('Monona', 'WI', 2358),
#  ('Berea', 'OH', 2347),
#  ('Carnegie', 'PA', 2342),
#  ('Canonsburg', 'PA', 2328),
#  ('Middleburg Heights', 'OH', 2264),
#  ('Twinsburg', 'OH', 2263),
#  ('Carefree', 'AZ', 2236),
#  ('Verona', 'WI', 2129),
#  ('Brunswick', 'OH', 2063),
#  ('Elyria', 'OH', 2053),
#  ('Aurora', 'OH', 2019),
#  ('Avon Lake', 'OH', 1919),
#  ('Unionville', 'ON', 1868),
#  ('East York', 'ON', 1826),
#  ('Harrisburg', 'NC', 1822),
#  ('Sewickley', 'PA', 1797),
#  ('Broadview Heights', 'OH', 1789),
#  ('Verdun', 'QC', 1765),
#  ('Streetsboro', 'OH', 1757),
#  ('Brossard', 'QC', 1741),
#  ('El Mirage', 'AZ', 1726),
#  ('North Royalton', 'OH', 1689),
#  ('West Mifflin', 'PA', 1685),
#  ('Concord', 'ON', 1665),
#  ('Monroe', 'NC', 1654),
#  ('Denver', 'NC', 1598),
#  ('LAS VEGAS', 'NV', 1559),
#  ('Buckeye', 'AZ', 1549),
#  ('Macedonia', 'OH', 1548),
#  ('Painesville', 'OH', 1522),
#  ('Mint Hill', 'NC', 1512),
#  ('Murrysville', 'PA', 1496),
#  ('Brooklyn', 'OH', 1496),
#  ('Spring Valley', 'NV', 1486),
#  ('Dorval', 'QC', 1439),
#  ('McMurray', 'PA', 1403),
#  ('Saint-Laurent', 'QC', 1380),
#  ('Brecksville', 'OH', 1321),
#  ('Indian Land', 'SC', 1297),
#  ('Northfield', 'OH', 1278),
#  ('Stoughton', 'WI', 1268),
#  ('Amherst', 'OH', 1264),
#  ('South Euclid', 'OH', 1245),
#  ('Gibsonia', 'PA', 1238),
#  ('Allison Park', 'PA', 1209),
#  ('Sun City West', 'AZ', 1209),
#  ('Airdrie', 'AB', 1188),
#  ('University Heights', 'OH', 1174),
#  ('York', 'ON', 1170),
#  ('Valley View', 'OH', 1158),
#  ('Bedford', 'OH', 1154),
#  ('Chesterland', 'OH', 1150),
#  ('Dollard-des-Ormeaux', 'QC', 1144),
#  ('Oakmont', 'PA', 1093),
#  ('Ahwatukee', 'AZ', 1042),
#  ('Kannapolis', 'NC', 1040),
#  ('North Ridgeville', 'OH', 1040),
#  ('Pointe-Claire', 'QC', 1034),
#  ('Moon Township', 'PA', 1033),
#  ('Euclid', 'OH', 1031),
#  ('Westmount', 'QC', 1024),
#  ('Savoy', 'IL', 1019),
#  ('Waunakee', 'WI', 1005),
#  ('Lorain', 'OH', 1003),
#  ('Dallas', 'TX', 991),
#  ('Lake Wylie', 'SC', 962),
#  ('Highland Heights', 'OH', 921),
#  ('Youngtown', 'AZ', 919),
#  ('Chardon', 'OH', 914),
#  ('Tega Cay', 'SC', 908),
#  ('West Homestead', 'PA', 905),
#  ('Parma Heights', 'OH', 902),
#  ('Warrensville Heights', 'OH', 888),
#  ('Summerlin', 'NV', 868),
#  ('Anthem', 'AZ', 865),
#  ('Olmsted Falls', 'OH', 861),
#  ('New Kensington', 'PA', 831),
#  ('Oregon', 'WI', 819),
#  ('Shaker Heights', 'OH', 817),
#  ('Irwin', 'PA', 813),
#  ('Eastlake', 'OH', 805),
#  ('Orange Village', 'OH', 798),
#  ('Wickliffe', 'OH', 770),
#  ('Brook Park', 'OH', 747),
#  ('Peninsula', 'OH', 742),
#  ('Mount Holly', 'NC', 741),
#  ('Bellevue', 'PA', 739),
#  ('Mount Horeb', 'WI', 732),
#  ('Willowick', 'OH', 725),
#  ('Maple', 'ON', 725),
#  ('South Las Vegas', 'NV', 720),
#  ('McKees Rocks', 'PA', 720),
#  ('Willoughby Hills', 'OH', 715),
#  ('Clover', 'SC', 715),
#  ('Seven Hills', 'OH', 710),
#  ('Whitchurch-Stouffville', 'ON', 705),
#  ('Tarentum', 'PA', 664),
#  ('Las Vegas', 'FL', 661),
#  ('Glenshaw', 'PA', 654),
#  ('Richfield', 'OH', 644),
#  ('Stouffville', 'ON', 636),
#  ('Verona', 'PA', 625),
#  ('Pleasant Hills', 'PA', 621),
#  ('Bay Village', 'OH', 615),
#  ('Mooresville', 'NC', 599),
#  ('Tallmadge', 'OH', 597),
#  ('Blue Diamond', 'NV', 596),
#  ('Higley', 'AZ', 580),
#  ('Robinson Township', 'PA', 568),
#  ('Outremont', 'QC', 565),
#  ('Lasalle', 'QC', 530),
#  ('Stallings', 'NC', 528),
#  ('N. Las Vegas', 'NV', 528),
#  ('Guadalupe', 'AZ', 510),
#  ('Longueuil', 'QC', 508),
#  ('Paradise', 'NV', 507),
#  ('North Versailles', 'PA', 492),
#  ('Wesley Chapel', 'NC', 486),
#  ('Missisauga', 'ON', 483),
#  ('North Huntingdon', 'PA', 476),
#  ('HENDERSON', 'NV', 457),
#  ('DeForest', 'WI', 450),
#  ('McKeesport', 'PA', 444),
#  ('Las  Vegas', 'NV', 442),
#  ('N Las Vegas', 'NV', 435),
#  ('Oakdale', 'PA', 434),
#  ('Lachine', 'QC', 432),
#  ('Pepper Pike', 'OH', 431),
#  ('Mahomet', 'IL', 421),
#  ('Cramerton', 'NC', 414),
#  ('Richmond Heights', 'OH', 414),
#  ('Garfield Heights', 'OH', 413),
#  ('Rantoul', 'IL', 413),
#  ('Burton', 'OH', 411),
#  ('Copley', 'OH', 407),
#  ('Saint-Sauveur', 'QC', 402),
#  ('Pierrefonds', 'QC', 401),
#  ('Wadsworth', 'OH', 398),
#  ('Braddock', 'PA', 396),
#  ('Mayfield', 'OH', 392),
#  ('Sun Lakes', 'AZ', 391),
#  ('Mount Lebanon', 'PA', 390),
#  ('Cottage Grove', 'WI', 385),
#  ('Mt. Lebanon', 'PA', 384),
#  ('Mc Kees Rocks', 'PA', 381),
#  ('Cross Plains', 'WI', 376),
#  ('Ambridge', 'PA', 365),
#  ('Apache Junction', 'AZ', 362),
#  ('White Oak', 'PA', 354),
#  ('Munhall', 'PA', 347),
#  ('Vaudreuil-Dorion', 'QC', 344),
#  ('Bolton', 'ON', 343),
#  ('Halton Hills', 'ON', 340),
#  ('Sheffield Village', 'OH', 337),
#  ('Fort McDowell', 'AZ', 337),
#  ('Kirkland', 'QC', 332),
#  ('MESA', 'AZ', 323),
#  ('Moreland Hills', 'OH', 323),
#  ('Kirtland', 'OH', 321),
#  ('Laveen Village', 'AZ', 321),
#  ('Blakeney', 'NC', 315),
#  ('Lower Lawrenceville', 'PA', 309),
#  ('McFarland', 'WI', 304),
#  ('Middlefield', 'OH', 303),
#  ('Tremont', 'OH', 302),
#  ('Enterprise', 'NV', 301),
#  ('Mayfield Village', 'OH', 296),
#  ('Maple Heights', 'OH', 296),
#  ('Millvale', 'PA', 294),
#  ('Upper St Clair', 'PA', 294),
#  ('Woodmere Village', 'OH', 292),
#  ('De Forest', 'WI', 291),
#  ('Monticello', 'IL', 289),
#  ('Scottdale', 'AZ', 285),
#  ('Georgetown', 'ON', 281),
#  ('Mc Farland', 'WI', 281),
#  ('Aspinwall', 'PA', 280),
#  ('Springdale', 'PA', 280),
#  ('Munroe Falls', 'OH', 278),
#  ('Cecil', 'PA', 275),
#  ('Elizabeth', 'PA', 274),
#  ('Ross Township', 'PA', 268),
#  ('Orange', 'OH', 264),
#  ('Windsor', 'WI', 262),
#  ('Bedford Heights', 'OH', 262),
#  ('Concord Mills', 'NC', 261),
#  ('West View', 'PA', 258),
#  ('Valley City', 'OH', 257),
#  ('Rocky View', 'AB', 257),
#  ('Grand River', 'OH', 257),
#  ('Las vegas', 'NV', 257),
#  ('East Gwillimbury', 'ON', 256),
#  ('North Randall', 'OH', 254),
#  ('LasVegas', 'NV', 252),
#  ('Bradford', 'ON', 251),
#  ('Heidelberg', 'PA', 249),
#  ('Caledon', 'ON', 248),
#  ('Robinson', 'PA', 247),
#  ('Lowell', 'NC', 246),
#  ('Mont-Royal', 'QC', 243),
#  ('King City', 'ON', 240),
#  ('Clark', 'NV', 234),
#  ('Turtle Creek', 'PA', 232),
#  ('Leetsdale', 'PA', 230),
#  ('Concord', 'OH', 229),
#  ('Brentwood', 'PA', 227),
#  ('Mentor-on-the-Lake', 'OH', 223),
#  ('Penn Hills', 'PA', 218),
#  ('Waddell', 'AZ', 217),
#  ('Belleville', 'WI', 217),
#  ("L'Île-Perrot", 'QC', 215),
#  ('Dallas', 'NC', 215),
#  ('Trafford', 'PA', 214),
#  ('Lawrenceville', 'PA', 214),
#  ('Sharpsburg', 'PA', 213),
#  ('Newbury', 'OH', 211),
#  ('Finleyville', 'PA', 210),
#  ('Rexdale', 'ON', 207),
#  ('Upper Saint Clair', 'PA', 201),
#  ('Grafton', 'OH', 201),
#  ('Hampton Township', 'PA', 201),
#  ('Crafton', 'PA', 200),
#  ('Boucherville', 'QC', 200),
#  ('Moon', 'PA', 197),
#  ('TEMPE', 'AZ', 193),
#  ('Columbia Station', 'OH', 189),
#  ('Brookpark', 'OH', 188),
#  ('Clairton', 'PA', 184),
#  ('Plum', 'PA', 183),
#  ('Norton', 'OH', 183),
#  ('Imperial', 'PA', 181),
#  ('Etna', 'PA', 175),
#  ('Bradford West Gwillimbury', 'ON', 175),
#  ('Dollard-Des-Ormeaux', 'QC', 175),
#  ('Cheswick', 'PA', 173),
#  ('Locust', 'NC', 171),
#  ('Fairport Harbor', 'OH', 166),
#  ('Sainte-Anne-de-Bellevue', 'QC', 159),
#  ('Saint-Jean-sur-Richelieu', 'QC', 159),
#  ('Saint-Leonard', 'QC', 157),
#  ('Nellis AFB', 'NV', 156),
#  ('Chestermere', 'AB', 156),
#  ('Greenfield Park', 'QC', 156),
#  ('Midland', 'NC', 155),
#  ('Tornto', 'ON', 154),
#  ('CHARLOTTE', 'NC', 153),
#  ('Saint-Lambert', 'QC', 152),
#  ('Hinckley', 'OH', 148),
#  ('Mckees Rocks', 'PA', 146),
#  ('Saint-Hubert', 'QC', 144),
#  ('La Prairie', 'QC', 144),
#  ('Anjou', 'QC', 143),
#  ('Weddington', 'NC', 143),
#  ('McCandless Township', 'PA', 141),
#  ('charlotte', 'NC', 137),
#  ('Stanley', 'NC', 137),
#  ('Castle Shannon', 'PA', 136),
#  ('Mc Murray', 'PA', 135),
#  ('las vegas', 'NV', 134),
#  ('South Park Township', 'PA', 130),
#  ('Wilkinsburg', 'PA', 130),
#  ('Mt Lebanon', 'PA', 129),
#  ('Don Mills', 'ON', 127),
#  ('Sheffield', 'OH', 126),
#  ('Gates Mills', 'OH', 125),
#  ('Port Credit', 'ON', 121),
#  ('Montrose', 'OH', 120),
#  ('GILBERT', 'AZ', 119),
#  ('Monongahela', 'PA', 118),
#  ('Kleinburg', 'ON', 117),
#  ('Robinson Twp.', 'PA', 114),
#  ('South Park', 'PA', 113),
#  ('Bainbridge', 'OH', 113),
#  ('LaSalle', 'QC', 112),
#  ('Brooklin', 'ON', 111),
#  ('Emsworth', 'PA', 110),
#  ('Las Vegas ', 'NV', 110),
#  ('Saint-Léonard', 'QC', 108),
#  ('Glendale Az', 'AZ', 108),
#  ('Harrison City', 'PA', 107),
#  ('Shadyside', 'PA', 103),
#  ('Lower Burrell', 'PA', 103),
#  ('Charlotte ', 'NC', 101),
#  ('lyndhurst', 'OH', 101),
#  ('Downtown', 'PA', 100),
#  ('Ravenna', 'OH', 99),
#  ('W Henderson', 'NV', 99),
#  ('Saint Joseph', 'IL', 98),
#  ('Dormont', 'PA', 98),
#  ('Montral', 'QC', 98),
#  ('Green Tree', 'PA', 98),
#  ('Saint-Jérôme', 'QC', 96),
#  ('Oakland', 'PA', 96),
#  ('Pittsburg', 'PA', 95),
#  ('Avalon', 'PA', 95),
#  ('Black Earth', 'WI', 95),
#  ('Walton Hills', 'OH', 94),
#  ('Rosemère', 'QC', 94),
#  ('Sedona', 'AZ', 93),
#  ('Saint-Eustache', 'QC', 93),
#  ('Chambly', 'QC', 93),
#  ('Boisbriand', 'QC', 91),
#  ('SCOTTSDALE', 'AZ', 91),
#  ('Jefferson Hills', 'PA', 89),
#  ('Brookline', 'PA', 89),
#  ('Presto', 'PA', 88),
#  ('Richmond Hil', 'ON', 87),
#  ('Hudson', 'QC', 86),
#  ('Swissvale', 'PA', 86),
#  ('Upper St. Clair', 'PA', 85),
#  ('Ft. Mill', 'SC', 85),
#  ('Brooklyn', 'NY', 85),
#  ('phoenix', 'AZ', 83),
#  ('NORTH LAS VEGAS', 'NV', 82),
#  ('Dravosburg', 'PA', 81),
#  ('Mantua', 'OH', 81),
#  ('McAdenville', 'NC', 80),
#  ('Las Vegas & Henderson', 'NV', 80),
#  ('Beaconsfield', 'QC', 79),
#  ('Sheffield Lake', 'OH', 79),
#  ('Terrebonne', 'QC', 78),
#  ('Champlain', 'NY', 77),
#  ('Wilmerding', 'PA', 76),
#  ('Milton', 'ON', 75),
#  ('Peters Township', 'PA', 74),
#  ('N Ridgeville', 'OH', 74),
#  ('Etibicoke', 'ON', 74),
#  ('Arnold', 'PA', 74),
#  ('Nobleton', 'ON', 74),
#  ('N W Las Vegas', 'NV', 74),
#  ('St-Benoît de Mirabel', 'QC', 73),
#  ('W Spring Valley', 'NV', 73),
#  ('Sauk City', 'WI', 72),
#  ('Mcmurray', 'PA', 70),
#  ('Olmsted Township', 'OH', 70),
#  ('McCandless', 'PA', 70),
#  ('Oakwood Village', 'OH', 70),
#  ('Montréal-Ouest', 'QC', 69),
#  ('Rouses Point', 'NY', 68),
#  ('110 Las Vegas', 'NV', 68),
#  ('Henderston', 'NV', 67),
#  ('PHOENIX', 'AZ', 67),
#  ('Mint  Hill', 'NC', 67),
#  ('Paoli', 'WI', 66),
#  ('Sagamore Hills', 'OH', 66),
#  ('Centennial Hills', 'NV', 65),
#  ('Sainte-Julie', 'QC', 65),
#  ('SURPRISE', 'AZ', 64),
#  ('Vegas', 'NV', 64),
#  ('MADISON', 'WI', 63),
#  ('West Montréal', 'QC', 63),
#  ('Bath', 'OH', 62),
#  ('North Olmstead', 'OH', 62),
#  ('Middleburg Hts', 'OH', 62),
#  ('Uxbridge', 'ON', 61),
#  ('Rocky View County', 'AB', 61),
#  ('East Liberty', 'PA', 60),
#  ('Saint-Lazare', 'QC', 60),
#  ('Mc Donald', 'PA', 60),
#  ('Harmarville', 'PA', 59),
#  ('Wilkins Township', 'PA', 59),
#  ('Venetia', 'PA', 59),
#  ('Châteauguay', 'QC', 59),
#  ('Fort  Mill', 'SC', 59),
#  ('Blawnox', 'PA', 59),
#  ('Mcfarland', 'WI', 58),
#  ('Fort Mcdowell', 'AZ', 58),
#  ('Forest Hills', 'PA', 58),
#  ('Gormley', 'ON', 58),
#  ('Vimont', 'QC', 57),
#  ('boulder city', 'NV', 57),
#  ('Deforest', 'WI', 57),
#  ('Dollard-des Ormeaux', 'QC', 57),
#  ('Mentor On The Lake', 'OH', 56),
#  ('Sainte-Thérèse', 'QC', 56),
#  ('scottsdale', 'AZ', 56),
#  ('Montreal-Nord', 'QC', 55),
#  ('Blainville', 'QC', 54),
#  ('Sainte-Anne-De-Bellevue', 'QC', 53),
#  ('Medina Township', 'OH', 53),
#  ('Ben Avon', 'PA', 53),
#  ('Library', 'PA', 52),
#  ('Baldwin', 'PA', 52),
#  ('Balzac', 'AB', 52),
#  ('RIchmond Hill', 'ON', 51),
#  ('Sainte-Adèle', 'QC', 51),
#  ('Russellton', 'PA', 51),
#  ('Mirabel', 'QC', 50),
#  ('Schaumburg', 'IL', 50),
#  ('Bratenahl', 'OH', 49),
#  ('St Joseph', 'IL', 49),
#  ('La Salle', 'QC', 49),
#  ('Export', 'PA', 49),
#  ('Tuscola', 'IL', 48),
#  ('Willowdale', 'ON', 48),
#  ('East McKeesport', 'PA', 48),
#  ('York Regional Municipality', 'ON', 48),
#  ('henderson', 'NV', 47),
#  ('Delson', 'QC', 47),
#  ('Caledon East', 'ON', 47),
#  ('Harrisbug', 'NC', 47),
#  ('Saint-Hyacinthe', 'QC', 47),
#  ('Los Angeles', 'CA', 47),
#  ('Mont-Saint-Hilaire', 'QC', 46),
#  ('C Las Vegas', 'NV', 46),
#  ('Schomberg', 'ON', 46),
#  ('Beloeil', 'QC', 45),
#  ('Squirrel Hill', 'PA', 45),
#  ('Lower burrell', 'PA', 45),
#  ('GOODYEAR', 'AZ', 45),
#  ('Île des Soeurs', 'QC', 45),
#  ('York', 'SC', 44),
#  ('Chateauguay', 'QC', 44),
#  ('Oakwood', 'OH', 44),
#  ('Ogden', 'IL', 43),
#  ('Neville Island', 'PA', 43),
#  ('McDonald', 'PA', 43),
#  ('Hiram', 'OH', 43),
#  ('Warrensville Hts.', 'OH', 43),
#  ('mesa', 'AZ', 42),
#  ('Elizabeth Township', 'PA', 42),
#  ('Sunrise', 'NV', 42),
#  ('East Pittsburgh', 'PA', 42),
#  ('Dollard-Des Ormeaux', 'QC', 41),
#  ('Rio Verde', 'AZ', 41),
#  ('Rosemere', 'QC', 41),
#  ('Waterloo', 'ON', 41),
#  ('Central Henderson', 'NV', 40),
#  ('Shorewood Hills', 'WI', 40),
#  ('Glassport', 'PA', 39),
#  ('Henderson (Green Valley)', 'NV', 39),
#  ('Mentor On the', 'OH', 39),
#  ('King', 'ON', 39),
#  ('Herminie', 'PA', 39),
#  ('Lowesville', 'NC', 38),
#  ('Dane', 'WI', 38),
#  ('South Charlotte', 'NC', 38),
#  ('Rigaud', 'QC', 38),
#  ('PEORIA', 'AZ', 38),
#  ('Sainte-Adele', 'QC', 38),
#  ('Saint-Jerome', 'QC', 38),
#  ('Ranlo', 'NC', 37),
#  ('Saint-Bernard-de-Lacolle', 'QC', 37),
#  ('East Cleveland', 'OH', 37),
#  ('Phoenix, AZ', 'AZ', 37),
#  ('Richmond Hts', 'OH', 36),
#  ('Saint-Constant', 'QC', 36),
#  ('New Eagle', 'PA', 36),
#  ('Litchfield', 'AZ', 36),
#  ('Toronto Division', 'ON', 36),
#  ('Lagrange', 'OH', 36),
#  ('NELLIS AFB', 'NV', 35),
#  ('Las Vegas East', 'NV', 35),
#  ('Midnapore', 'AB', 35),
#  ('GIlbert', 'AZ', 35),
#  ('East Ajax', 'ON', 35),
#  ('San Diego', 'CA', 35),
#  ('LAVEEN', 'AZ', 34),
#  ('Fort Mill', 'NC', 34),
#  ('Lachute', 'QC', 34),
#  ('Broadview Hts', 'OH', 34),
#  ('North Hills', 'PA', 34),
#  ('Kennedy Township', 'PA', 33),
#  ('Saint-Henri', 'QC', 33),
#  ('Columbus', 'WI', 33),
#  ('Brooklyn', 'WI', 33),
#  ('St-Jerome', 'QC', 32),
#  ('North Toronto', 'ON', 32),
#  ('Bellvue', 'PA', 32),
#  ('Montréal-Nord', 'QC', 32),
#  ('Wildwood', 'PA', 32),
#  ('Mckeesport', 'PA', 32),
#  ('Beeton', 'ON', 31),
#  ('Phoenix', 'TX', 31),
#  ('Mont-Saint-Grégoire', 'QC', 31),
#  ('Mount Albert', 'ON', 31),
#  ('MONROEVILLE', 'PA', 30),
#  ('Montreal-West', 'QC', 30),
#  ('Kahnawake', 'QC', 30),
#  ('Goodwood', 'ON', 30),
#  ('Shaler Township', 'PA', 30),
#  ('Downsview', 'ON', 29),
#  ('Philo', 'IL', 29),
#  ('Richmonhill', 'ON', 29),
#  ("L'ile-Perrot", 'QC', 29),
#  ('Mascouche', 'QC', 29),
#  ('Morgan Hill', 'CA', 29),
#  ('INDIAN LAND', 'SC', 29),
#  ('Morin-Heights', 'QC', 28),
#  ('Montrèal', 'QC', 28),
#  ('Brunswick Hills', 'OH', 28),
#  ('Sidney', 'IL', 27),
#  ('Elrama', 'PA', 27),
#  ('Cleveland Hghts.', 'OH', 27),
#  ('cave creek', 'AZ', 27),
#  ('St-Leonard', 'QC', 27),
#  ('Oka', 'QC', 27),
#  ('Duquesne', 'PA', 26),
#  ('Bainbridge Township', 'OH', 26),
#  ('Mount Washington', 'PA', 26),
#  ('Belle Vernon', 'PA', 26),
#  ('Concord Township', 'OH', 26),
#  ('Mcknight', 'PA', 26),
#  ('Mayfield Heights (Cleveland)', 'OH', 26),
#  ('Boston Heights', 'OH', 26),
#  ('Oberlin', 'OH', 26),
#  ('Edgewood', 'PA', 26),
#  ('Saint-Sauveur-des-Monts', 'QC', 26),
#  ('Monoroeville', 'PA', 25),
#  ('Seven Hills', 'NV', 25),
#  ('Litchfield', 'OH', 25),
#  ('Scarobrough', 'ON', 25),
#  ('Northwest Calgary', 'AB', 25),
#  ('Central City Village', 'AZ', 25),
#  ('Rankin', 'PA', 25),
#  ('Marshall', 'WI', 25),
#  ('Central', 'AZ', 25),
#  ('N. Olmsted', 'OH', 25),
#  ('Homer', 'IL', 25),
#  ('East Mc Keesport', 'PA', 24),
#  ('Auburn Township', 'OH', 24),
#  ('Northfield Center', 'OH', 24),
#  ('New River', 'AZ', 24),
#  ('City Center', 'NV', 24),
#  ('Joliette', 'QC', 24),
#  ('Gilbert', 'FL', 23),
#  ('Cote Saint-Luc', 'QC', 23),
#  ('Sainte-Genevieve', 'QC', 23),
#  ('North of Brampton', 'ON', 23),
#  ('Rocky View No. 44', 'AB', 23),
#  ('Le Sud-Ouest', 'QC', 23),
#  ('McKeesRocks', 'PA', 23),
#  ('Downtown Toronto', 'ON', 23),
#  ("L'Île-Bizard", 'QC', 22),
#  ('Piedmont', 'QC', 22),
#  ('Peninsula', 'CA', 22),
#  ('Promenade', 'NC', 22),
#  ('Rostraver', 'PA', 22),
#  ('Pheonix', 'AZ', 22),
#  ('Perry', 'OH', 22),
#  ('Saint-Bruno-de-Montarville', 'QC', 22),
#  ('FORT MILL', 'SC', 22),
#  ('Thornhil', 'ON', 22),
#  ('Bedford Hts', 'OH', 22),
#  ('Phx', 'AZ', 22),
#  ('Mentor On the Lake', 'OH', 22),
#  ('Cuyahoga Heights', 'OH', 22),
#  ('Grand Canyon', 'AZ', 21),
#  ('Montreal-Ouest', 'QC', 21),
#  ('Queen creek', 'AZ', 21),
#  ('Durham Regional Municipality', 'ON', 21),
#  ('N E Las Vegas', 'NV', 21),
#  ('Urbana, Illinois', 'IL', 21),
#  ('North Huntington', 'PA', 21),
#  ('Pointe-Aux-Trembles', 'QC', 21),
#  ('St-Bruno-de-Montarville', 'QC', 21),
#  ('toronto', 'ON', 21),
#  ('Communauté-Urbaine-de-Montréal', 'QC', 21),
#  ('San Tan Valley', 'AZ', 21),
#  ('Tottenham', 'ON', 21),
#  ('LaGrange', 'OH', 20),
#  ('Ste-Rose', 'QC', 20),
#  ('Streetsville', 'ON', 20),
#  ('CONCORD', 'NC', 20),
#  ('Indian land', 'NC', 20),
#  ('Lufkin', 'TX', 20),
#  ('Nellis Afb', 'NV', 20),
#  ('Geauga', 'OH', 20),
#  ('Nellis Air Force Base', 'NV', 20),
#  ('Clarkson', 'ON', 20),
#  ('Charlotte', 'SC', 19),
#  ('\u200bChandler', 'AZ', 19),
#  ('East Mississauga', 'ON', 19),
#  ('Repentigny', 'QC', 19),
#  ('moon', 'PA', 19),
#  ('Allentown', 'PA', 19),
#  ('Novelty', 'OH', 19),
#  ("Notre-Dame-de-l'Ile-Perrot", 'QC', 18),
#  ('Troy Township', 'OH', 18),
#  ('Pitcairn', 'PA', 18),
#  ('Saint-Bruno', 'QC', 18),
#  ('Creighton', 'PA', 18),
#  ('Estérel', 'QC', 18),
#  ('Franklin Park', 'PA', 18),
#  ('Shaker Hts', 'OH', 18),
#  ('Whiitby', 'ON', 18),
#  ('Lakewood, Oh', 'OH', 18),
#  ('TORONTO', 'ON', 18),
#  ('Scottsdale, AZ', 'AZ', 18),
#  ('University Ht', 'OH', 17),
#  ('Warrensville Hts', 'OH', 17),
#  ('Fort mill', 'SC', 17),
#  ('Temecula', 'CA', 17),
#  ('Warrensville', 'OH', 17),
#  ('Cleveland Heigh', 'OH', 17),
#  ('Mt Holly', 'NC', 17),
#  ('Pine', 'PA', 17),
#  ('Hendersonville', 'PA', 17),
#  ('University Hts ', 'OH', 17),
#  ('Moon TWP', 'PA', 17),
#  ('Glen Williams', 'ON', 17),
#  ('Ballantyne', 'NC', 17),
#  ('Ahwahtukee', 'AZ', 17),
#  ('Holland Landing', 'ON', 17),
#  ('Pointe Claire', 'QC', 17),
#  ('Sainte-Catherine', 'QC', 17),
#  ('Erie', 'OH', 17),
#  ('New York', 'NY', 17),
#  ('Mesa AZ', 'AZ', 16),
#  ('Regional Municipality of York', 'ON', 16),
#  ('Cuddy', 'PA', 16),
#  ('Chargrin Falls', 'OH', 16),
#  ('Rural Ridge', 'PA', 16),
#  ('Northfield Center Township', 'OH', 16),
#  ('Lawrence', 'PA', 16),
#  ('St Leonard', 'QC', 16),
#  ('Barberton', 'OH', 16),
#  ('Moon Twp', 'PA', 16),
#  ('Brooklyn Heights', 'OH', 16),
#  ('kirtland', 'OH', 16),
#  ('Highland Hills', 'OH', 16),
#  ('Rawdon', 'QC', 15),
#  ('Saint-Marc-sur-Richelieu', 'QC', 15),
#  ('GASTONIA', 'NC', 15),
#  ('Saint-Philippe', 'QC', 15),
#  ('Red Mountain', 'AZ', 15),
#  ('Las Vegas Nv', 'CA', 15),
#  ('Roxboro', 'QC', 15),
#  ('Sainte-Anne-des-Plaines', 'QC', 15),
#  ('MACEDONIA', 'OH', 15),
#  ('Las Vegas, NV', 'NV', 15),
#  ('Oshawa', 'ON', 15),
#  ('Median', 'OH', 15),
#  ('Ashburn', 'ON', 15),
#  ('AVON', 'OH', 15),
#  ('Lancaster', 'SC', 15),
#  ('Cuyahoga Fls', 'OH', 15),
#  ('Mathews', 'NC', 15),
#  ('Saint Laurent', 'QC', 15),
#  ('tempe', 'AZ', 15),
#  ('East Mesa', 'AZ', 15),
#  ('North Strabane Township', 'PA', 14),
#  ('Harrisburg,', 'NC', 14),
#  ('Etobiicoke', 'ON', 14),
#  ('Russell Twp', 'OH', 14),
#  ('North Charlotte', 'NC', 14),
#  ('Mt. Holly', 'NC', 14),
#  ('Green Valley', 'NV', 14),
#  ('Yorkville', 'ON', 14),
#  ('River Drive Park', 'ON', 14),
#  ('Cooksville', 'ON', 14),
#  ('North Las Vegas', 'NY', 14),
#  ('Indian land', 'SC', 14),
#  ('Las Vegas', 'NM', 14),
#  ('Eighty Four', 'PA', 14),
#  ('Division No. 6', 'AB', 14),
#  ('Summerlin South', 'NV', 14),
#  ('Phoenx', 'AZ', 14),
#  ('Westport', 'NC', 14),
#  ('Phoenix ', 'AZ', 14),
#  ('Hyland Heights', 'OH', 14),
#  ('Middleburg Hts.', 'OH', 13),
#  ('South Amherst', 'OH', 13),
#  ('surprise', 'AZ', 13),
#  ('Deerfield', 'WI', 13),
#  ('Marvin', 'NC', 13),
#  ('Hendserson', 'NV', 13),
#  ('Mercier', 'QC', 13),
#  ('North Scottsdale', 'AZ', 13),
#  ('Salaberry-De-Valleyfield', 'QC', 13),
#  ('Sunnyslope', 'AZ', 13),
#  ('Cranberry Twp', 'PA', 13),
#  ('Gifford', 'IL', 13),
#  ('Arrowhead', 'AZ', 13),
#  ('Ville Mont-Royal', 'QC', 13),
#  ('Thorncliffe Park', 'ON', 13),
#  ('Schottsdale', 'AZ', 12),
#  ('Clinton', 'PA', 12),
#  ('N. Randall', 'OH', 12),
#  ('PARMA HEIGHTS', 'OH', 12),
#  ('Mt. Horeb', 'WI', 12),
#  ('Weston', 'ON', 12),
#  ('Indian Trail', 'OH', 12),
#  ('glendale', 'AZ', 12),
#  ('Black Rock City', 'NV', 12),
#  ('Fabreville', 'QC', 12),
#  ('Salaberry-de-Valleyfield', 'QC', 12),
#  ('Kirkland', 'WA', 12),
#  ('Phoenix,', 'AZ', 12),
#  ('Rillton', 'PA', 12),
#  ('Montgomery', 'NC', 12),
#  ('Oak Ridges', 'ON', 12),
#  ('South Hills', 'PA', 12),
#  ('Ahwatukee Foothills Village', 'AZ', 11),
#  ('Ross', 'PA', 11),
#  ('Pittsburgh ', 'PA', 11),
#  ('Avondale', 'GA', 11),
#  ('Phoenix Metro Area', 'AZ', 11),
#  ('Indianola', 'PA', 11),
#  ('Saint-Jean-Sur-Richelieu', 'QC', 11),
#  ('Pheonix AZ', 'AZ', 11),
#  ('Ville Saint Laurent', 'QC', 11),
#  ('Surprise', 'CA', 11),
#  ('Pincourt', 'QC', 11),
#  ('Southeast Calgary', 'AB', 11),
#  ('Edmonton', 'AB', 11),
#  ('Saint-Hippolyte', 'QC', 11),
#  ('Antioch', 'CA', 11),
#  ('Scottadale', 'CA', 11),
#  ('Central City', 'AZ', 11),
#  ('McMurry', 'PA', 11),
#  ('Québec', 'QC', 11),
#  ('Mississuaga', 'ON', 11),
#  ('Cote-Saint-Luc', 'QC', 11),
#  ('Côte Saint-Luc', 'QC', 10),
#  ('North  York', 'ON', 10),
#  ('Inglewood', 'ON', 10),
#  ('Candiac', 'QC', 10),
#  ('Hudson', 'FL', 10),
#  ('Phoeniix', 'AZ', 10),
#  ('Las Vegas', 'CA', 10),
#  ('Berry', 'WI', 10),
#  ('Huntington Beach', 'CA', 10),
#  ('Lake Norman', 'NC', 10),
#  ('Rockyview', 'AB', 10),
#  ('Malton', 'ON', 10),
#  ('East Calgary', 'AB', 10),
#  ('Auburn Twp', 'OH', 10),
#  ('Sturgeon', 'PA', 10),
#  ('Chandler-Gilbert', 'AZ', 10),
#  ("Baie-d'Urfe", 'QC', 10),
#  ('Canonsburd', 'PA', 10),
#  ('Silver Lake', 'OH', 10),
#  ('Wellington', 'OH', 9),
#  ('verdun', 'QC', 9),
#  ('Lynhurst', 'OH', 9),
#  ('Sainte-Thérèse-de-Blainville', 'QC', 9),
#  ('Ansnorveldt', 'ON', 9),
#  ('Bois-des-Filion', 'QC', 9),
#  ('Ingram', 'PA', 9),
#  ('Noyan', 'QC', 9),
#  ('Brooklyn Hts.', 'OH', 9),
#  ('Toronto', 'OH', 9),
#  ('Moseley', 'VA', 9),
#  ('S Concord', 'NC', 9),
#  ('Farmington', 'CT', 9),
#  ('Fisher', 'IL', 9),
#  ('North Braddock', 'PA', 9),
#  ('Gelndale', 'AZ', 9),
#  ('Char', 'NC', 9),
#  ('Beauharnois', 'QC', 9),
#  ('Côte-Saint-Luc', 'QC', 9),
#  ('N. Ridgeville', 'OH', 9),
#  ('Vaudreuil', 'QC', 9),
#  ('Sainte-Therese', 'QC', 9),
#  ('Tolono', 'IL', 9),
#  ('Hampstead', 'QC', 9),
#  ('Valleywide', 'AZ', 9),
#  ('Monreoville', 'PA', 9),
#  ('GLENDALE', 'AZ', 9),
#  ('Harwick', 'PA', 9),
#  ('Pointe-Calumet', 'QC', 8),
#  ('Alberta', 'AB', 8),
#  ('North Carolina', 'NC', 8),
#  ('Surprise Crossing', 'AZ', 8),
#  ('Huntsburg', 'OH', 8),
#  ('Val-Morin', 'QC', 8),
#  ('Erie', 'PA', 8),
#  ('Montréal-West', 'QC', 8),
#  ('Reminderville', 'OH', 8),
#  ('West Toronto', 'ON', 8),
#  ('Chandler', 'CA', 8),
#  ('North Las Vegas ', 'NV', 8),
#  ('ETOBICOKE', 'ON', 8),
#  ('Las Vegas,', 'NV', 8),
#  ('solon', 'OH', 8),
#  ('Omaha', 'NE', 8),
#  ('Nevada', 'NV', 8),
#  ('Sainte-Adèle', 'AB', 8),
#  ('Mooers', 'NY', 8),
#  ('springdale', 'PA', 8),
#  ('Mayfield Heights.', 'OH', 8),
#  ('Old Town Scottsdale', 'AZ', 8),
#  ('Napierville', 'QC', 8),
#  ('SCARBOROUGH', 'ON', 8),
#  ('CLEVELAND', 'OH', 8),
#  ('Montéal', 'QC', 8),
#  ('Las Vegass', 'NV', 8),
#  ('Parma mid birth', 'OH', 8),
#  ('SW Calgary', 'AB', 8),
#  ('Leeds', 'XWY', 8),
#  ('Tucson', 'AZ', 8),
#  ('Bradfordwoods', 'PA', 8),
#  ('Union', 'NJ', 8),
#  ('Pahrump', 'NV', 8),
#  ('Lake Park', 'NC', 8),
#  ('Bedford', 'QC', 7),
#  ('Mayfield Hts', 'OH', 7),
#  ('Peninsul', 'OH', 7),
#  ('Bedford Hts.', 'OH', 7),
#  ('AGINCOURT', 'ON', 7),
#  ('Garfield Hts', 'OH', 7),
#  ('The Promenade', 'AZ', 7),
#  ('Pepperpike', 'OH', 7),
#  ('Norval', 'ON', 7),
#  ('Plum Boro', 'PA', 7),
#  ('Ingomar', 'PA', 7),
#  ('Lachenaie', 'QC', 7),
#  ('Decatur', 'NV', 7),
#  ('Bloomfield', 'PA', 7),
#  ('Pittsburgh', 'VA', 7),
#  ('Mount Oliver', 'PA', 7),
#  ('Fitchburgh', 'WI', 7),
#  ('Las Vegas', 'TX', 7),
#  ('NEWMARKET', 'ON', 7),
#  ('Avon lake', 'OH', 7),
#  ('Prévost', 'QC', 7),
#  ('Valencia', 'PA', 7),
#  ('Buckeye - Shaker', 'OH', 7),
#  ('St.Pittsburgh', 'PA', 7),
#  ('Westview', 'PA', 7),
#  ('Painesville Township', 'OH', 7),
#  ('Old Brooklyn', 'OH', 7),
#  ('Desert Ridge', 'AZ', 7),
#  ('Scarbrough', 'ON', 7),
#  ('La Vegas', 'NV', 7),
#  ('Hemmingford', 'QC', 7),
#  ('Saint-Charles-Borromee', 'QC', 7),
#  ('Strongville', 'OH', 7),
#  ("Baie-d'Urfé", 'QC', 7),
#  ('Coteau-du-Lac', 'QC', 7),
#  ('Mccandless Township', 'PA', 7),
#  ('Buena Vista', 'PA', 7),
#  ('Spartanburg', 'SC', 7),
#  ('Regent Square', 'PA', 7),
#  ('Henderson and Las vegas', 'NV', 7),
#  ('Concord Twp', 'OH', 7),
#  ('Monticello', 'AR', 7),
#  ('Beachwood ', 'OH', 7),
#  ('Warrendale', 'PA', 6),
#  ('Allegheny', 'PA', 6),
#  ('Broadlands', 'IL', 6),
#  ('Charlemagne', 'QC', 6),
#  ('San Tan', 'AZ', 6),
#  ('Quartier des Spectacles', 'QC', 6),
#  ('Zephyr', 'ON', 6),
#  ('CAVE CREEK', 'AZ', 6),
#  ('Saint - Hyacinthe', 'QC', 6),
#  ('Farnham', 'QC', 6),
#  ('markham', 'ON', 6),
#  ('Markham, ON', 'ON', 6),
#  ('Shady Side', 'PA', 6),
#  ('THORNHILL', 'ON', 6),
#  ('Sutersville', 'PA', 6),
#  ('NORTH YORK', 'ON', 6),
#  ('Chatauguay', 'QC', 6),
#  ('Woodbridge (Vaughan)', 'ON', 6),
#  ('Gilbert', 'CA', 6),
#  ('Kettleby', 'ON', 6),
#  ('Huntingdon', 'QC', 6),
#  ('Mattews', 'NC', 6),
#  ('Old Scottsdale', 'AZ', 6),
#  ('Ormstown', 'QC', 6),
#  ('West Elizabeth', 'PA', 6),
#  ('Greenway', 'AZ', 6),
#  ('Whtiby', 'ON', 6),
#  ('Phoenix AZ', 'AZ', 6),
#  ('Lodi', 'WI', 6),
#  ('Westworld Scottsdale', 'AZ', 6),
#  ('DENVER', 'NC', 6),
#  ('Montréal (Québec)', 'QC', 6),
#  ('Sunrise Manor', 'NV', 6),
#  ('Cleveland, OH', 'OH', 6),
#  ('Chander', 'AZ', 6),
#  ('Deux-Montagnes Regional County Municipality', 'QC', 6),
#  ("L'ile-Bizard", 'QC', 6),
#  ('Morgan', 'PA', 6),
#  ('Saintt-Bruno-de-Montarville', 'QC', 6),
#  ('Litchfield park', 'AZ', 6),
#  ('Villa Grove', 'IL', 6),
#  ('Estrella Village', 'AZ', 5),
#  ('St. Jean Sur Richelieu', 'QC', 5),
#  ('Crescent', 'PA', 5),
#  ('Rocky river', 'OH', 5),
#  ('Caledon Village', 'ON', 5),
#  ('University', 'NC', 5),
#  ('Las Vegas', 'AZ', 5),
#  ('East Gwilimbury', 'ON', 5),
#  ('Fox Chapel', 'PA', 5),
#  ("Notre-Dame-De-L'ile-Perrot", 'QC', 5),
#  ("L'assomption", 'QC', 5),
#  ('Sainte-Marthe', 'QC', 5),
#  ('North York', 'AB', 5),
#  ('Alburg', 'VT', 5),
#  ('Mentor-On-The-Lake', 'OH', 5),
#  ('Strip District', 'PA', 5),
#  ('Chertsey', 'QC', 5),
#  ('Side Slopes', 'PA', 5),
#  ('Northyork', 'ON', 5),
#  ('Agincourt', 'ON', 5),
#  ('Bakerstown', 'PA', 5),
#  ('Sage Hill', 'AB', 5),
#  ('Otterburn Park', 'QC', 5),
#  ('Spring Hill City View', 'PA', 5),
#  ('Lake Las Vegas', 'NV', 5),
#  ('Toronto', 'AB', 5),
#  ('Southside Flats', 'PA', 5),
#  ('Beltline', 'AB', 5),
#  ('Mesa Arizona', 'AZ', 5),
#  ('Rougemont', 'QC', 5),
#  ('Cave Creek Road', 'AZ', 5),
#  ('Lindale', 'OH', 5),
#  ('Whitney', 'NV', 5),
#  ('Saint-Basile-Le-Grand', 'QC', 5),
#  ('Henderson Nevada', 'AL', 5),
#  ('Île-des-Soeurs', 'QC', 5),
#  ("De l'Eglise", 'QC', 5),
#  ('East Credit', 'ON', 5),
#  ('Leaside', 'ON', 5),
#  ('Montville', 'OH', 5),
#  ('Glendale', 'CT', 4),
#  ('St. Leonard', 'QC', 4),
#  ('Dublin', 'CA', 4),
#  ('Nationwide', 'CA', 4),
#  ('Penn Hills Township', 'PA', 4),
#  ('Saint-Pierre-de-Véronne-à-Pike-River', 'QC', 4),
#  ('QUEEN CREEK', 'AZ', 4),
#  ('Stetson Valley', 'AZ', 4),
#  ('Pennsylvania', 'PA', 4),
#  ('Bath', 'BAS', 4),
#  ('Mc Adenville', 'NC', 4),
#  ('Nottingham Township', 'PA', 4),
#  ('Saint-Bernard de Lacolle', 'QC', 4),
#  ('Auburn', 'OH', 4),
#  ('Draper', 'UT', 4),
#  ('Pasadena', 'AZ', 4),
#  ('Frazer', 'PA', 4),
#  ('Yorkdale', 'ON', 4),
#  ('Joliet', 'IL', 4),
#  ('Mcdonald', 'PA', 4),
#  ('Palgrave', 'ON', 4),
#  ('Paw Creek', 'NC', 4),
#  ('Fithian', 'IL', 4),
#  ('Montreal', 'AB', 4),
#  ('Saint-Isidore-de-Laprairie', 'QC', 4),
#  ('south Euclid', 'OH', 4),
#  ('Phoenix Valley', 'AZ', 4),
#  ('Blue Mounds', 'WI', 4),
#  ('Chandler', 'AL', 4),
#  ('Mt. Washington', 'PA', 4),
#  ('Iberville', 'QC', 4),
#  ('Claremont', 'ON', 4),
#  ('Sale', 'XGM', 4),
#  ('Greensboro', 'NC', 4),
#  ('Etobicoke,', 'ON', 4),
#  ('Highland Hts', 'OH', 4),
#  ('Murrysville (Monroeville)', 'PA', 4),
#  ('Sainte-Marguerite-du-lac-Masson', 'QC', 4),
#  ('Sandy Ridge', 'NC', 4),
#  ('Saint-Pie', 'QC', 4),
#  ('North Olmsted,', 'OH', 4),
#  ('Queen Creek', 'AK', 4),
#  ('Metro Phoenix', 'AZ', 4),
#  ('Venise-en-Québec', 'QC', 4),
#  ('Point-Claire', 'QC', 4),
#  ('Closter', 'NY', 4),
#  ('Mississauge', 'ON', 4),
#  ('Newburgh Heights', 'OH', 4),
#  ('Saint Leonard', 'QC', 4),
#  ('montreal', 'QC', 4),
#  ('Tampa', 'FL', 4),
#  ('North  Ridgeville', 'OH', 4),
#  ('Cave creek', 'AZ', 4),
#  ('Mayfield Hts.', 'OH', 4),
#  ('Mississauaga', 'ON', 4),
#  ('McKnight', 'PA', 4),
#  ('Phoniex', 'AZ', 4),
#  ('Harmar Township', 'PA', 4),
#  ('charlottte', 'NC', 4),
#  ("L'Assomption", 'QC', 4),
#  ('Highland Park', 'AB', 4),
#  ('Sainte-Marguerite-Esterel', 'QC', 4),
#  ('Toronto-North York', 'ON', 4),
#  ('Sainte-Marguerite-du-Lac-Masson', 'QC', 4),
#  ('Milford', 'OH', 4),
#  ('Down', 'DOW', 4),
#  ('Varennes', 'QC', 4),
#  ('Oakridges', 'ON', 4),
#  ('Monterey Park', 'CA', 4),
#  ('Las Vegas', 'NC', 4),
#  ('De Winton', 'AB', 4),
#  ('Central Oakland', 'PA', 4),
#  ('Shaler', 'PA', 4),
#  ('Arizona', 'AZ', 4),
#  ('Richland Township', 'PA', 4),
#  ('New Tecumseth', 'ON', 4),
#  ('Glbert', 'AZ', 4),
#  ('Phoneix', 'AZ', 4),
#  ('MATTHEWS', 'NC', 4),
#  ('Rock Hill SC', 'SC', 4),
#  ('Centre Island', 'ON', 4),
#  ('Rainbow Valley', 'AZ', 4),
#  ('Las Vegas', 'NE', 4),
#  ('Bentleyville', 'OH', 4),
#  ('Dewey', 'IL', 4),
#  ('Toronto Scarborough', 'ON', 4),
#  ('Snowflake', 'AZ', 4),
#  ('Sainte-Dorothée', 'QC', 4),
#  ('Darlington', 'SC', 4),
#  ('Sainte-Madeleine', 'QC', 4),
#  ('Moon Twp.', 'PA', 4),
#  ('Scotesdale', 'AZ', 4),
#  ('South Russell', 'OH', 4),
#  ('calgary', 'AB', 4),
#  ('Pittsburch', 'PA', 4),
#  ('Lavaltrie', 'QC', 3),
#  ('Catawba Springs', 'NC', 3),
#  ('Sainte-Geneviève', 'QC', 3),
#  ('Wilkens Township', 'PA', 3),
#  ('Montreal-Quest', 'QC', 3),
#  ('Medicine Hat', 'AB', 3),
#  ('oakville', 'ON', 3),
#  ('Rockyview County', 'AB', 3),
#  ('Los Vegas', 'NV', 3),
#  ('Downtown', 'AB', 3),
#  ('Rockey View', 'AB', 3),
#  ('Laval, Ste Dorothee', 'QC', 3),
#  ('Henryville', 'QC', 3),
#  ('Manchester', 'XGM', 3),
#  ('Austin', 'TX', 3),
#  ('Cuyohoga Falls', 'OH', 3),
#  ('Mansfield', 'IL', 3),
#  ('Suprise', 'AZ', 3),
#  ('', 'AZ', 3),
#  ('East Hawkesbury', 'ON', 3),
#  ('Vaughn', 'ON', 3),
#  ('Oldham', 'XGM', 3),
#  ('Deux-Montagnes', 'QC', 3),
#  ('Sharon', 'ON', 3),
#  ('North Phoenix', 'AZ', 3),
#  ('Cote Saint Luc', 'QC', 3),
#  ('North york', 'ON', 3),
#  ('Sainte-thérèse', 'QC', 3),
#  ('Alburgh', 'VT', 3),
#  ('Scottsale', 'AZ', 3),
#  ('Northeast Calgary', 'AB', 3),
#  ('Tempe ', 'AZ', 3),
#  ('NorthYork', 'ON', 3),
#  ('TOLLESON', 'AZ', 3),
#  ('Indian Land,', 'SC', 3),
#  ('Sainte-Rose', 'QC', 3),
#  ('Boston', 'PA', 3),
#  ('Canonsburg', 'WA', 3),
#  ('Seattle', 'WI', 3),
#  ('Fountain Hls', 'AZ', 3),
#  ('Lacolle', 'QC', 3),
#  ('Litchfield', 'CT', 3),
#  ('Crouse', 'NC', 3),
#  ('London', 'XGL', 3),
#  ('Hamilton', 'ON', 3),
#  ('Port Vue', 'PA', 3),
#  ('Montréal-Est', 'QC', 3),
#  ('Thomasboro', 'IL', 3),
#  ('St. Sauveur', 'QC', 3),
#  ('Cleveland Height', 'OH', 3),
#  ('AZ', 'AZ', 3),
#  ('las Vegas', 'NV', 3),
#  ('Midway', 'PA', 3),
#  ('Grove City', 'OH', 3),
#  ('Chomedey, Laval', 'QC', 3),
#  ('Pointe-aux-Trembles', 'QC', 3),
#  ('McMasterville', 'QC', 3),
#  ('Township of Concord', 'OH', 3),
#  ('SUN PRAIRIE', 'WI', 3),
#  ('Les Coteaux', 'QC', 3),
#  ('Las Vegas Nevada', 'NV', 3),
#  ('Calgary', 'AL', 3),
#  ('Evergreen', 'AB', 3),
#  ('Richmond Height', 'OH', 3),
#  ('Richmond Hill', 'BC', 3),
#  ('Banksville', 'PA', 3),
#  ('Madison', 'OH', 3),
#  ('Hnederson', 'NV', 3),
#  ('St-Laurent', 'QC', 3),
#  ('Las Vegas Valley', 'NV', 3),
#  ('Somerton', 'AZ', 3),
#  ('Red Rock', 'AZ', 3),
#  ('CALGARY', 'AB', 3),
#  ('Scotsdale', 'AZ', 3),
#  ('Brownsburg-Chatham', 'QC', 3),
#  ('Queensville', 'ON', 3),
#  ('Godmanchester', 'QC', 3),
#  ('New Glarus', 'WI', 3),
#  ('West Lake', 'OH', 3),
#  ('Laval, Pont Viau', 'QC', 3),
#  ('Church Cove', 'CON', 3),
#  ('Ste-Dorothée', 'QC', 3),
#  ('Burlington', 'ON', 3),
#  ('St-Clet', 'QC', 3),
#  ('Montreal-Est', 'QC', 3),
#  ('Columbia Sta', 'OH', 3),
#  ('Sun Praiie', 'WI', 3),
#  ('Edgemont', 'AB', 3),
#  ('Leslieville', 'ON', 3),
#  ('Mont St-hilaire', 'QC', 3),
#  ('St. Léonard', 'QC', 3),
#  ('Vieux-Montréal', 'QC', 3),
#  ('Mississaugua', 'ON', 3),
#  ('Maple Grove', 'QC', 3),
#  ('Oakwood village', 'OH', 3),
#  ('Lake Mead', 'NV', 3),
#  ('Ste-Therese-de-Blainville', 'QC', 3),
#  ('Nellis', 'NV', 3),
#  ('Ange-Gardien', 'QC', 3),
#  ('St-Jean-sur-Richelieu', 'QC', 3),
#  ('Warrenville', 'OH', 3),
#  ('etobicoke', 'ON', 3),
#  ('Sacramento', 'CA', 3),
#  ('Citibank', 'NV', 3),
#  ('Les Cèdres', 'QC', 3),
#  ('Le Haut-Saint-Laurent Regional County Municipality', 'QC', 3),
#  ('N Solon', 'OH', 3),
#  ('Pgh Int Arprt', 'PA', 3),
#  ('Las Vergas', 'NV', 3),
#  ('Toronto-West', 'ON', 3),
#  ('Garrettsville', 'OH', 3),
#  ('Ivesdale', 'IL', 3),
#  ('Pickering Ajax Whitby', 'ON', 3),
#  ('CARSON', 'PA', 3),
#  ('Twinsburgh', 'OH', 3),
#  ('Berea', 'AK', 3),
#  ('Middleburg', 'OH', 3),
#  ('Chattanooga', 'TN', 3),
#  ('Bury', 'XGM', 3),
#  ('Old Port of Montreal', 'QC', 3),
#  ('Maricopa', 'AZ', 3),
#  ('Cranberry Township', 'PA', 3),
#  ('Suncity', 'AZ', 3),
#  ('Perry Twp', 'OH', 3),
#  ('Mississagua', 'ON', 3),
#  ('Vaughan Mills', 'ON', 3),
#  ('Belœil', 'QC', 3),
#  ('Uptown', 'OH', 3),
#  ('St. Joseph', 'IL', 3),
#  ('Apache Trail', 'AZ', 3),
#  ('Bond Head', 'ON', 3),
#  ('Sun CIty', 'AZ', 3),
#  ('St-Lazare', 'QC', 3),
#  ('Puyallup', 'WA', 3),
#  ("O'hara Township", 'PA', 3),
#  ('Saint-laurent', 'QC', 3),
#  ('Saint-Basile-le-Grand', 'QC', 3),
#  ("Saint-Roch-de-l'Achigan", 'QC', 3),
#  ('Aliquippa', 'PA', 3),
#  ('CAREFREE', 'AZ', 3),
#  ('peoria', 'AZ', 3),
#  ('Chateau', 'PA', 3),
#  ('Thornhill', 'DUR', 3),
#  ('Cleveland Hts.', 'OH', 3),
#  ('Las Vegas NV', 'NV', 3),
#  ('Toronto-Etobicoke', 'ON', 3),
#  ('Las Vegas', 'GA', 3)]
